# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import mutual_info_regression
from scipy import stats

# 读取数据
df = pd.read_csv('/root/Download/Modis-algae-aliyun/AlgaeBloomForecast-20241107/merged_all_data_filtered.csv')

# 添加风力大于4级的特征
df['strong_wind'] = df['wind_power'].apply(lambda x: 1 if str(x).replace('级','').isdigit() and int(str(x).replace('级','')) >= 4 else 0)

# 选择需要分析相关性的列
target_cols = ['density_mean_y', 'density_lower_y', 'density_upper_y', 
               'chla_mean', 'chla_lower', 'chla_upper']

# 选择数值型特征列,排除目标列、日期列和density_x相关列
exclude_cols = target_cols + ['date', 'density_mean_x', 'density_lower_x', 'density_upper_x']
feature_cols = df.select_dtypes(include=[np.number]).columns.difference(exclude_cols)

# 1. 使用Spearman相关系数分析非线性相关性
spearman_corr = df[list(feature_cols) + target_cols].corr(method='spearman')

# 2. 计算互信息得分
mi_scores = {}
for target in target_cols:
    mi_scores[target] = {}
    for feature in feature_cols:
        mi_score = mutual_info_regression(df[[feature]], df[target], random_state=42)[0]
        mi_scores[target][feature] = mi_score

# 3. 高级滞后相关性分析
max_lag = 15
lag_analysis = {}

for target in target_cols:
    lag_analysis[target] = {}
    
    for feature in feature_cols:
        lag_analysis[target][feature] = {
            'pearson': [],
            'spearman': [],
            'kendall': [],
            'granger_causality': []
        }
        
        for lag in range(1, max_lag + 1):
            # Pearson相关系数
            pearson = df[feature].shift(lag).corr(df[target])
            
            # Spearman相关系数
            spearman = df[feature].shift(lag).corr(df[target], method='spearman')
            
            # Kendall相关系数
            kendall = df[feature].shift(lag).corr(df[target], method='kendall')
            
            # Granger因果关系检验
            feature_lagged = df[feature].shift(lag).dropna()
            target_aligned = df[target][lag:]
            if len(feature_lagged) > lag:
                granger_test = stats.pearsonr(feature_lagged, target_aligned[:len(feature_lagged)])[0]
            else:
                granger_test = np.nan
                
            lag_analysis[target][feature]['pearson'].append(pearson)
            lag_analysis[target][feature]['spearman'].append(spearman)
            lag_analysis[target][feature]['kendall'].append(kendall)
            lag_analysis[target][feature]['granger_causality'].append(granger_test)

# 4. 特征重要性综合评分
feature_importance = {}
for target in target_cols:
    feature_importance[target] = {}
    
    for feature in feature_cols:
        # 计算综合得分
        abs_corr = abs(spearman_corr.loc[feature, target])
        mi_score = mi_scores[target][feature]
        max_lag_corr = max([abs(x) for x in lag_analysis[target][feature]['spearman'] if not np.isnan(x)], default=0)
        
        # 综合评分 = 0.4*相关系数 + 0.3*互信息 + 0.3*最大滞后相关
        composite_score = 0.4 * abs_corr + 0.3 * mi_score + 0.3 * max_lag_corr
        feature_importance[target][feature] = composite_score

# 输出关键影响因子
print("关键影响因子分析结果:")
for target in target_cols:
    print(f"\n目标变量 {target} 的top 10关键影响因子:")
    
    # 按综合得分排序
    sorted_features = sorted(feature_importance[target].items(), 
                           key=lambda x: x[1], 
                           reverse=True)[:10]
    
    for feature, score in sorted_features:
        best_lag = np.argmax([abs(x) for x in lag_analysis[target][feature]['spearman']]) + 1
        print(f"特征: {feature}")
        print(f"- 综合重要性得分: {score:.3f}")
        print(f"- Spearman相关系数: {spearman_corr.loc[feature, target]:.3f}")
        print(f"- 最佳滞后期: {best_lag}天")
        print(f"- 互信息得分: {mi_scores[target][feature]:.3f}")
        print()

# 天气特征分析
df = pd.read_csv('merged_all_data_filtered.csv')
df['date'] = pd.to_datetime(df['date'])
df.set_index('date', inplace=True)

# 添加风力大于4级的特征
df['strong_wind'] = df['wind_power'].apply(lambda x: 1 if str(x).replace('级','').isdigit() and int(str(x).replace('级','')) >= 4 else 0)

def split_weather(weather):
    if pd.isna(weather):
        return []
    return str(weather).split('-')

all_weather_types = set()
for weather in df['weather'].dropna():
    all_weather_types.update(split_weather(weather))

for weather_type in all_weather_types:
    df[f'weather_{weather_type}'] = df['weather'].apply(lambda x: 1 if pd.notna(x) and weather_type in split_weather(x) else 0)

weather_features = [col for col in df.columns if col.startswith('weather_')] + ['strong_wind']

# 对天气特征进行同样的分析
weather_importance = {}
for target in target_cols:
    weather_importance[target] = {}
    
    for feature in weather_features:
        # 计算基本相关性
        corr = df[feature].corr(df[target], method='spearman')
        
        # 计算最大滞后相关性
        lag_corrs = []
        for lag in range(1, max_lag + 1):
            lag_corr = df[feature].shift(lag).corr(df[target], method='spearman')
            lag_corrs.append(lag_corr if not np.isnan(lag_corr) else 0)
        
        max_lag_corr = max([abs(x) for x in lag_corrs])
        best_lag = np.argmax([abs(x) for x in lag_corrs]) + 1
        
        weather_importance[target][feature] = {
            'correlation': corr,
            'max_lag_correlation': max_lag_corr,
            'best_lag': best_lag
        }

# 输出天气影响分析结果
print("\n天气因素影响分析结果:")
for target in target_cols:
    print(f"\n目标变量 {target} 的主要天气影响因子:")
    
    sorted_weather = sorted(weather_importance[target].items(), 
                          key=lambda x: abs(x[1]['correlation']), 
                          reverse=True)[:5]
    
    for feature, metrics in sorted_weather:
        print(f"天气类型: {feature.replace('weather_','')}")
        print(f"- 相关系数: {metrics['correlation']:.3f}")
        print(f"- 最佳滞后期: {metrics['best_lag']}天")
        print(f"- 最大滞后相关: {metrics['max_lag_correlation']:.3f}")
        print()
# Out:
# 关键影响因子分析结果:
#
# 目标变量 density_mean_y 的top 10关键影响因子:
# 特征: temperature
# - 综合重要性得分: 0.533
# - Spearman相关系数: 0.561
# - 最佳滞后期: 7天
# - 互信息得分: 0.450
#
# 特征: min_temperature
# - 综合重要性得分: 0.476
# - Spearman相关系数: 0.546
# - 最佳滞后期: 4天
# - 互信息得分: 0.282
#
# 特征: max_temperature
# - 综合重要性得分: 0.469
# - Spearman相关系数: 0.533
# - 最佳滞后期: 3天
# - 互信息得分: 0.267
#
# 特征: oxygen
# - 综合重要性得分: 0.426
# - Spearman相关系数: -0.440
# - 最佳滞后期: 15天
# - 互信息得分: 0.329
#
# 特征: TN
# - 综合重要性得分: 0.412
# - Spearman相关系数: -0.442
# - 最佳滞后期: 4天
# - 互信息得分: 0.316
#
# 特征: conductivity
# - 综合重要性得分: 0.411
# - Spearman相关系数: -0.412
# - 最佳滞后期: 5天
# - 互信息得分: 0.401
#
# 特征: pH
# - 综合重要性得分: 0.328
# - Spearman相关系数: 0.335
# - 最佳滞后期: 1天
# - 互信息得分: 0.306
#
# 特征: aqi
# - 综合重要性得分: 0.256
# - Spearman相关系数: -0.351
# - 最佳滞后期: 1天
# - 互信息得分: 0.078
#
# 特征: aqiLevel
# - 综合重要性得分: 0.247
# - Spearman相关系数: -0.330
# - 最佳滞后期: 1天
# - 互信息得分: 0.095
#
# 特征: TP
# - 综合重要性得分: 0.241
# - Spearman相关系数: 0.272
# - 最佳滞后期: 1天
# - 互信息得分: 0.216
#
#
# 目标变量 density_lower_y 的top 10关键影响因子:
# 特征: temperature
# - 综合重要性得分: 0.447
# - Spearman相关系数: 0.465
# - 最佳滞后期: 3天
# - 互信息得分: 0.382
#
# 特征: min_temperature
# - 综合重要性得分: 0.413
# - Spearman相关系数: 0.470
# - 最佳滞后期: 5天
# - 互信息得分: 0.250
#
# 特征: max_temperature
# - 综合重要性得分: 0.396
# - Spearman相关系数: 0.448
# - 最佳滞后期: 3天
# - 互信息得分: 0.218
#
# 特征: oxygen
# - 综合重要性得分: 0.386
# - Spearman相关系数: -0.392
# - 最佳滞后期: 15天
# - 互信息得分: 0.349
#
# 特征: TN
# - 综合重要性得分: 0.343
# - Spearman相关系数: -0.350
# - 最佳滞后期: 4天
# - 互信息得分: 0.299
#
# 特征: conductivity
# - 综合重要性得分: 0.340
# - Spearman相关系数: -0.343
# - 最佳滞后期: 5天
# - 互信息得分: 0.333
#
# 特征: TP
# - 综合重要性得分: 0.285
# - Spearman相关系数: 0.330
# - 最佳滞后期: 1天
# - 互信息得分: 0.234
#
# 特征: pH
# - 综合重要性得分: 0.279
# - Spearman相关系数: 0.243
# - 最佳滞后期: 3天
# - 互信息得分: 0.343
#
# 特征: aqi
# - 综合重要性得分: 0.253
# - Spearman相关系数: -0.333
# - 最佳滞后期: 1天
# - 互信息得分: 0.115
#
# 特征: turbidity
# - 综合重要性得分: 0.250
# - Spearman相关系数: 0.308
# - 最佳滞后期: 1天
# - 互信息得分: 0.179
#
#
# 目标变量 density_upper_y 的top 10关键影响因子:
# 特征: temperature
# - 综合重要性得分: 0.532
# - Spearman相关系数: 0.586
# - 最佳滞后期: 7天
# - 互信息得分: 0.390
#
# 特征: min_temperature
# - 综合重要性得分: 0.493
# - Spearman相关系数: 0.564
# - 最佳滞后期: 4天
# - 互信息得分: 0.299
#
# 特征: max_temperature
# - 综合重要性得分: 0.482
# - Spearman相关系数: 0.555
# - 最佳滞后期: 3天
# - 互信息得分: 0.264
#
# 特征: TN
# - 综合重要性得分: 0.423
# - Spearman相关系数: -0.469
# - 最佳滞后期: 3天
# - 互信息得分: 0.295
#
# 特征: oxygen
# - 综合重要性得分: 0.417
# - Spearman相关系数: -0.448
# - 最佳滞后期: 15天
# - 互信息得分: 0.267
#
# 特征: conductivity
# - 综合重要性得分: 0.406
# - Spearman相关系数: -0.428
# - 最佳滞后期: 5天
# - 互信息得分: 0.349
#
# 特征: pH
# - 综合重要性得分: 0.333
# - Spearman相关系数: 0.362
# - 最佳滞后期: 1天
# - 互信息得分: 0.263
#
# 特征: aqi
# - 综合重要性得分: 0.259
# - Spearman相关系数: -0.347
# - 最佳滞后期: 1天
# - 互信息得分: 0.091
#
# 特征: aqiLevel
# - 综合重要性得分: 0.232
# - Spearman相关系数: -0.327
# - 最佳滞后期: 1天
# - 互信息得分: 0.053
#
# 特征: permanganate
# - 综合重要性得分: 0.211
# - Spearman相关系数: 0.219
# - 最佳滞后期: 1天
# - 互信息得分: 0.246
#
#
# 目标变量 chla_mean 的top 10关键影响因子:
# 特征: pH
# - 综合重要性得分: 0.294
# - Spearman相关系数: 0.342
# - 最佳滞后期: 1天
# - 互信息得分: 0.215
#
# 特征: permanganate
# - 综合重要性得分: 0.196
# - Spearman相关系数: 0.237
# - 最佳滞后期: 1天
# - 互信息得分: 0.138
#
# 特征: TP
# - 综合重要性得分: 0.176
# - Spearman相关系数: 0.198
# - 最佳滞后期: 11天
# - 互信息得分: 0.140
#
# 特征: max_temperature
# - 综合重要性得分: 0.174
# - Spearman相关系数: 0.203
# - 最佳滞后期: 2天
# - 互信息得分: 0.084
#
# 特征: temperature
# - 综合重要性得分: 0.162
# - Spearman相关系数: 0.150
# - 最佳滞后期: 1天
# - 互信息得分: 0.195
#
# 特征: min_temperature
# - 综合重要性得分: 0.152
# - Spearman相关系数: 0.180
# - 最佳滞后期: 14天
# - 互信息得分: 0.088
#
# 特征: TN
# - 综合重要性得分: 0.143
# - Spearman相关系数: -0.101
# - 最佳滞后期: 15天
# - 互信息得分: 0.149
#
# 特征: oxygen
# - 综合重要性得分: 0.113
# - Spearman相关系数: -0.082
# - 最佳滞后期: 15天
# - 互信息得分: 0.114
#
# 特征: b4
# - 综合重要性得分: 0.105
# - Spearman相关系数: -0.114
# - 最佳滞后期: 2天
# - 互信息得分: 0.037
#
# 特征: b1
# - 综合重要性得分: 0.103
# - Spearman相关系数: -0.114
# - 最佳滞后期: 2天
# - 互信息得分: 0.029
#
#
# 目标变量 chla_lower 的top 10关键影响因子:
# 特征: pH
# - 综合重要性得分: 0.278
# - Spearman相关系数: 0.327
# - 最佳滞后期: 1天
# - 互信息得分: 0.183
#
# 特征: TP
# - 综合重要性得分: 0.206
# - Spearman相关系数: 0.232
# - 最佳滞后期: 1天
# - 互信息得分: 0.180
#
# 特征: permanganate
# - 综合重要性得分: 0.206
# - Spearman相关系数: 0.249
# - 最佳滞后期: 1天
# - 互信息得分: 0.142
#
# 特征: max_temperature
# - 综合重要性得分: 0.173
# - Spearman相关系数: 0.195
# - 最佳滞后期: 2天
# - 互信息得分: 0.089
#
# 特征: temperature
# - 综合重要性得分: 0.154
# - Spearman相关系数: 0.147
# - 最佳滞后期: 1天
# - 互信息得分: 0.172
#
# 特征: TN
# - 综合重要性得分: 0.142
# - Spearman相关系数: -0.118
# - 最佳滞后期: 15天
# - 互信息得分: 0.125
#
# 特征: min_temperature
# - 综合重要性得分: 0.140
# - Spearman相关系数: 0.178
# - 最佳滞后期: 14天
# - 互信息得分: 0.045
#
# 特征: oxygen
# - 综合重要性得分: 0.116
# - Spearman相关系数: -0.097
# - 最佳滞后期: 7天
# - 互信息得分: 0.099
#
# 特征: aqi
# - 综合重要性得分: 0.100
# - Spearman相关系数: -0.130
# - 最佳滞后期: 12天
# - 互信息得分: 0.024
#
# 特征: b4
# - 综合重要性得分: 0.096
# - Spearman相关系数: -0.100
# - 最佳滞后期: 2天
# - 互信息得分: 0.028
#
#
# 目标变量 chla_upper 的top 10关键影响因子:
# 特征: pH
# - 综合重要性得分: 0.285
# - Spearman相关系数: 0.346
# - 最佳滞后期: 1天
# - 互信息得分: 0.180
#
# 特征: permanganate
# - 综合重要性得分: 0.195
# - Spearman相关系数: 0.226
# - 最佳滞后期: 1天
# - 互信息得分: 0.161
#
# 特征: max_temperature
# - 综合重要性得分: 0.166
# - Spearman相关系数: 0.203
# - 最佳滞后期: 1天
# - 互信息得分: 0.061
#
# 特征: TP
# - 综合重要性得分: 0.161
# - Spearman相关系数: 0.175
# - 最佳滞后期: 11天
# - 互信息得分: 0.129
#
# 特征: min_temperature
# - 综合重要性得分: 0.158
# - Spearman相关系数: 0.178
# - 最佳滞后期: 1天
# - 互信息得分: 0.114
#
# 特征: temperature
# - 综合重要性得分: 0.152
# - Spearman相关系数: 0.147
# - 最佳滞后期: 1天
# - 互信息得分: 0.167
#
# 特征: TN
# - 综合重要性得分: 0.139
# - Spearman相关系数: -0.091
# - 最佳滞后期: 15天
# - 互信息得分: 0.149
#
# 特征: oxygen
# - 综合重要性得分: 0.113
# - Spearman相关系数: -0.072
# - 最佳滞后期: 15天
# - 互信息得分: 0.125
#
# 特征: b2
# - 综合重要性得分: 0.113
# - Spearman相关系数: -0.114
# - 最佳滞后期: 3天
# - 互信息得分: 0.061
#
# 特征: b4
# - 综合重要性得分: 0.108
# - Spearman相关系数: -0.120
# - 最佳滞后期: 3天
# - 互信息得分: 0.038
#
#
# 天气因素影响分析结果:
#
# 目标变量 density_mean_y 的主要天气影响因子:
# 天气类型: 雨夹雪
# - 相关系数: -0.088
# - 最佳滞后期: 15天
# - 最大滞后相关: 0.116
#
# 天气类型: strong_wind
# - 相关系数: 0.073
# - 最佳滞后期: 12天
# - 最大滞后相关: 0.055
#
# 天气类型: 雷阵雨
# - 相关系数: 0.062
# - 最佳滞后期: 3天
# - 最大滞后相关: 0.094
#
# 天气类型: 小雨
# - 相关系数: -0.061
# - 最佳滞后期: 5天
# - 最大滞后相关: 0.073
#
# 天气类型: 雨
# - 相关系数: 0.059
# - 最佳滞后期: 1天
# - 最大滞后相关: 0.072
#
#
# 目标变量 density_lower_y 的主要天气影响因子:
# 天气类型: 小雨
# - 相关系数: -0.089
# - 最佳滞后期: 2天
# - 最大滞后相关: 0.131
#
# 天气类型: 雨
# - 相关系数: 0.088
# - 最佳滞后期: 1天
# - 最大滞后相关: 0.096
#
# 天气类型: 雨夹雪
# - 相关系数: -0.077
# - 最佳滞后期: 5天
# - 最大滞后相关: 0.113
#
# 天气类型: 霾
# - 相关系数: 0.074
# - 最佳滞后期: 13天
# - 最大滞后相关: 0.103
#
# 天气类型: 多云
# - 相关系数: -0.069
# - 最佳滞后期: 15天
# - 最大滞后相关: 0.101
#
#
# 目标变量 density_upper_y 的主要天气影响因子:
# 天气类型: 雨夹雪
# - 相关系数: -0.090
# - 最佳滞后期: 15天
# - 最大滞后相关: 0.121
#
# 天气类型: strong_wind
# - 相关系数: 0.083
# - 最佳滞后期: 1天
# - 最大滞后相关: 0.058
#
# 天气类型: 雷阵雨
# - 相关系数: 0.076
# - 最佳滞后期: 3天
# - 最大滞后相关: 0.109
#
# 天气类型: 中雪
# - 相关系数: -0.060
# - 最佳滞后期: 14天
# - 最大滞后相关: 0.062
#
# 天气类型: 小雪
# - 相关系数: -0.049
# - 最佳滞后期: 15天
# - 最大滞后相关: 0.045
#
#
# 目标变量 chla_mean 的主要天气影响因子:
# 天气类型: 阴
# - 相关系数: -0.157
# - 最佳滞后期: 3天
# - 最大滞后相关: 0.173
#
# 天气类型: 小雨
# - 相关系数: -0.136
# - 最佳滞后期: 7天
# - 最大滞后相关: 0.167
#
# 天气类型: 霾
# - 相关系数: 0.126
# - 最佳滞后期: 7天
# - 最大滞后相关: 0.160
#
# 天气类型: 雾
# - 相关系数: 0.115
# - 最佳滞后期: 8天
# - 最大滞后相关: 0.140
#
# 天气类型: 阵雨
# - 相关系数: -0.102
# - 最佳滞后期: 2天
# - 最大滞后相关: 0.104
#
#
# 目标变量 chla_lower 的主要天气影响因子:
# 天气类型: 阴
# - 相关系数: -0.140
# - 最佳滞后期: 3天
# - 最大滞后相关: 0.159
#
# 天气类型: 小雨
# - 相关系数: -0.124
# - 最佳滞后期: 2天
# - 最大滞后相关: 0.164
#
# 天气类型: 霾
# - 相关系数: 0.117
# - 最佳滞后期: 7天
# - 最大滞后相关: 0.160
#
# 天气类型: 雾
# - 相关系数: 0.109
# - 最佳滞后期: 8天
# - 最大滞后相关: 0.135
#
# 天气类型: 阵雨
# - 相关系数: -0.105
# - 最佳滞后期: 1天
# - 最大滞后相关: 0.097
#
#
# 目标变量 chla_upper 的主要天气影响因子:
# 天气类型: 阴
# - 相关系数: -0.164
# - 最佳滞后期: 3天
# - 最大滞后相关: 0.181
#
# 天气类型: 小雨
# - 相关系数: -0.141
# - 最佳滞后期: 7天
# - 最大滞后相关: 0.168
#
# 天气类型: 霾
# - 相关系数: 0.124
# - 最佳滞后期: 7天
# - 最大滞后相关: 0.155
#
# 天气类型: 雾
# - 相关系数: 0.117
# - 最佳滞后期: 8天
# - 最大滞后相关: 0.136
#
# 天气类型: 阵雨
# - 相关系数: -0.097
# - 最佳滞后期: 2天
# - 最大滞后相关: 0.108

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import mutual_info_regression
from scipy import stats

# 读取数据
df = pd.read_csv('/root/Download/Modis-algae-aliyun/AlgaeBloomForecast-20241107/merged_all_data_filtered.csv')
df['date'] = pd.to_datetime(df['date'])

# 添加风力大于4级的特征
df['strong_wind'] = df['wind_power'].apply(lambda x: 1 if str(x).replace('级','').isdigit() and int(str(x).replace('级','')) >= 4 else 0)

# 添加天气one-hot编码
def split_weather(weather):
    if pd.isna(weather):
        return []
    return str(weather).split('-')

all_weather_types = set()
for weather in df['weather'].dropna():
    all_weather_types.update(split_weather(weather))

for weather_type in all_weather_types:
    df[f'weather_{weather_type}'] = df['weather'].apply(lambda x: 1 if pd.notna(x) and weather_type in split_weather(x) else 0)

# 选择需要分析相关性的列
target_cols = ['density_mean_y', 'density_lower_y', 'density_upper_y', 
               'chla_mean', 'chla_lower', 'chla_upper']

# 选择所有特征列
exclude_cols = target_cols + ['date', 'density_mean_x', 'density_lower_x', 'density_upper_x', 'weather']
feature_cols = df.select_dtypes(include=[np.number]).columns.difference(exclude_cols)

# 计算综合特征重要性
feature_importance = {}
for target in target_cols:
    feature_importance[target] = {}
    
    for feature in feature_cols:
        # Spearman相关系数
        spearman_corr = df[feature].corr(df[target], method='spearman')
        
        # 互信息得分
        mi_score = mutual_info_regression(df[[feature]], df[target], random_state=42)[0]
        
        # 滞后相关性
        max_lag_corr = 0
        best_lag = 0
        for lag in range(1, 16):
            lag_corr = df[feature].shift(lag).corr(df[target], method='spearman')
            if not np.isnan(lag_corr) and abs(lag_corr) > abs(max_lag_corr):
                max_lag_corr = lag_corr
                best_lag = lag
                
        # 综合评分 = 0.4*相关系数 + 0.3*互信息 + 0.3*最大滞后相关
        composite_score = 0.4 * abs(spearman_corr) + 0.3 * mi_score + 0.3 * abs(max_lag_corr)
        
        feature_importance[target][feature] = {
            'composite_score': composite_score,
            'spearman_corr': spearman_corr,
            'mi_score': mi_score,
            'max_lag_corr': max_lag_corr,
            'best_lag': best_lag
        }
# 创建结果表格
results = []
for target in target_cols:
    sorted_features = sorted(feature_importance[target].items(), 
                           key=lambda x: x[1]['composite_score'], 
                           reverse=True)[:15]
    
    for feature, metrics in sorted_features:
        results.append({
            '目标变量': target,
            '特征': feature,
            '综合得分': round(metrics['composite_score'], 3),
            'Spearman相关系数': round(metrics['spearman_corr'], 3),
            '互信息得分': round(metrics['mi_score'], 3),
            '最大滞后相关': round(metrics['max_lag_corr'], 3),
            '最佳滞后期(天)': metrics['best_lag']
        })

# 输出结果表格
results_df = pd.DataFrame(results)
print("\n各目标变量的Top 15影响因子:")
print(results_df.to_string(index=False))
# Out:
# 各目标变量的Top 15影响因子:
#            目标变量              特征  综合得分  Spearman相关系数  互信息得分  最大滞后相关  最佳滞后期(天)
#  density_mean_y     temperature 0.533         0.561  0.450   0.580         7
#  density_mean_y min_temperature 0.476         0.546  0.282   0.577         4
#  density_mean_y max_temperature 0.469         0.533  0.267   0.585         3
#  density_mean_y          oxygen 0.426        -0.440  0.329  -0.505        15
#  density_mean_y              TN 0.412        -0.442  0.316  -0.468         4
#  density_mean_y    conductivity 0.411        -0.412  0.401  -0.420         5
#  density_mean_y              pH 0.328         0.335  0.306   0.342         1
#  density_mean_y             aqi 0.256        -0.351  0.078  -0.309         1
#  density_mean_y        aqiLevel 0.247        -0.330  0.095  -0.288         1
#  density_mean_y              TP 0.241         0.272  0.216   0.224         1
#  density_mean_y    permanganate 0.230         0.235  0.272   0.182         1
#  density_mean_y       turbidity 0.227         0.290  0.155   0.215         1
#  density_mean_y              NH 0.136        -0.133  0.127  -0.148        15
#  density_mean_y             FAI 0.131         0.156  0.025   0.203        11
#  density_mean_y            nrfi 0.107        -0.117  0.038  -0.163         7
# density_lower_y     temperature 0.447         0.465  0.382   0.488         3
# density_lower_y min_temperature 0.413         0.470  0.250   0.499         5
# density_lower_y max_temperature 0.396         0.448  0.218   0.506         3
# density_lower_y          oxygen 0.386        -0.392  0.349  -0.414        15
# density_lower_y              TN 0.343        -0.350  0.299  -0.380         4
# density_lower_y    conductivity 0.340        -0.343  0.333  -0.342         5
# density_lower_y              TP 0.285         0.330  0.234   0.277         1
# density_lower_y              pH 0.279         0.243  0.343   0.263         3
# density_lower_y             aqi 0.253        -0.333  0.115  -0.284         1
# density_lower_y       turbidity 0.250         0.308  0.179   0.245         1
# density_lower_y        aqiLevel 0.234        -0.308  0.097  -0.273         1
# density_lower_y    permanganate 0.233         0.248  0.244   0.201         1
# density_lower_y             FAI 0.104         0.122  0.018   0.166        14
# density_lower_y             evi 0.088        -0.090  0.063  -0.112        11
# density_lower_y              NH 0.087        -0.055  0.159  -0.058        13
# density_upper_y     temperature 0.532         0.586  0.390   0.603         7
# density_upper_y min_temperature 0.493         0.564  0.299   0.593         4
# density_upper_y max_temperature 0.482         0.555  0.264   0.601         3
# density_upper_y              TN 0.423        -0.469  0.295  -0.491         3
# density_upper_y          oxygen 0.417        -0.448  0.267  -0.528        15
# density_upper_y    conductivity 0.406        -0.428  0.349  -0.435         5
# density_upper_y              pH 0.333         0.362  0.263   0.363         1
# density_upper_y             aqi 0.259        -0.347  0.091  -0.310         1
# density_upper_y        aqiLevel 0.232        -0.327  0.053  -0.286         1
# density_upper_y    permanganate 0.211         0.219  0.246   0.166         1
# density_upper_y              TP 0.189         0.226  0.146   0.183         1
# density_upper_y       turbidity 0.186         0.259  0.087   0.188         1
# density_upper_y              NH 0.167        -0.172  0.134  -0.192        15
# density_upper_y             FAI 0.144         0.165  0.043   0.216        11
# density_upper_y            nrfi 0.118        -0.138  0.031  -0.178         7
#       chla_mean              pH 0.294         0.342  0.215   0.309         1
#       chla_mean    permanganate 0.196         0.237  0.138   0.197         1
#       chla_mean              TP 0.176         0.198  0.140   0.181        11
#       chla_mean max_temperature 0.174         0.203  0.084   0.226         2
#       chla_mean     temperature 0.162         0.150  0.195   0.146         1
#       chla_mean min_temperature 0.152         0.180  0.088   0.180        14
#       chla_mean              TN 0.143        -0.101  0.149  -0.194        15
#       chla_mean       weather_阴 0.127        -0.157  0.042  -0.173         3
#       chla_mean          oxygen 0.113        -0.082  0.114  -0.154        15
#       chla_mean      weather_小雨 0.113        -0.136  0.029  -0.167         7
#       chla_mean              b4 0.105        -0.114  0.037  -0.162         2
#       chla_mean       weather_霾 0.105         0.126  0.022   0.160         7
#       chla_mean              b1 0.103        -0.114  0.029  -0.162         2
#       chla_mean              b3 0.100        -0.112  0.025  -0.158         2
#       chla_mean              b2 0.097        -0.109  0.020  -0.160         3
#      chla_lower              pH 0.278         0.327  0.183   0.306         1
#      chla_lower              TP 0.206         0.232  0.180   0.199         1
#      chla_lower    permanganate 0.206         0.249  0.142   0.212         1
#      chla_lower max_temperature 0.173         0.195  0.089   0.228         2
#      chla_lower     temperature 0.154         0.147  0.172   0.146         1
#      chla_lower              TN 0.142        -0.118  0.125  -0.190        15
#      chla_lower min_temperature 0.140         0.178  0.045   0.184        14
#      chla_lower          oxygen 0.116        -0.097  0.099  -0.156         7
#      chla_lower       weather_阴 0.111        -0.140  0.025  -0.159         3
#      chla_lower      weather_小雨 0.102        -0.124  0.009  -0.164         2
#      chla_lower             aqi 0.100        -0.130  0.024  -0.135        12
#      chla_lower              b4 0.096        -0.100  0.028  -0.158         2
#      chla_lower       weather_霾 0.095         0.117  0.000   0.160         7
#      chla_lower              b5 0.094        -0.091  0.046  -0.147         2
#      chla_lower              b3 0.094        -0.098  0.026  -0.156         2
#      chla_upper              pH 0.285         0.346  0.180   0.308         1
#      chla_upper    permanganate 0.195         0.226  0.161   0.187         1
#      chla_upper max_temperature 0.166         0.203  0.061   0.220         1
#      chla_upper              TP 0.161         0.175  0.129   0.176        11
#      chla_upper min_temperature 0.158         0.178  0.114   0.176         1
#      chla_upper     temperature 0.152         0.147  0.167   0.142         1
#      chla_upper              TN 0.139        -0.091  0.149  -0.194        15
#      chla_upper       weather_阴 0.125        -0.164  0.018  -0.181         3
#      chla_upper      weather_小雨 0.114        -0.141  0.024  -0.168         7
#      chla_upper          oxygen 0.113        -0.072  0.125  -0.154        15
#      chla_upper              b2 0.113        -0.114  0.061  -0.163         3
#      chla_upper              b4 0.108        -0.120  0.038  -0.164         3
#      chla_upper              b1 0.108        -0.120  0.036  -0.164         3
#      chla_upper    conductivity 0.106         0.057  0.194  -0.083        15
#      chla_upper              b5 0.102        -0.108  0.043  -0.153         3
