# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import matplotlib.pyplot as plt

# 读取两个CSV文件
mod_df = pd.read_csv('特征和密度结果_MODIS_MOD09GA_061_20241106_插值填充_tuoshan2.csv')
mcd_df = pd.read_csv('特征和密度结果_MODIS_MCD18C2_061_20241104_插值填充_tuoshan.csv')

# 重命名MCD数据框中的密度列,以区分来源
mcd_df = mcd_df.rename(columns={
    'density_mean': 'density_mean_mcd',
    'density_lower': 'density_lower_mcd', 
    'density_upper': 'density_upper_mcd'
})

# 重命名MOD数据框中的密度列
mod_df = mod_df.rename(columns={
    'density_mean': 'density_mean_mod',
    'density_lower': 'density_lower_mod',
    'density_upper': 'density_upper_mod'
})

# 合并两个数据框,以date为键
merged_df = pd.merge(mod_df, mcd_df, on='date')

# 计算两个来源的平均值作为最终密度值
merged_df['density_mean'] = merged_df['density_mean_mod']
merged_df['density_lower'] = merged_df['density_lower_mod']
merged_df['density_upper'] = merged_df['density_upper_mod']

# %%
# pip install seaborn -i https://mirrors.aliyun.com/pypi/simple/

# %%
# pip install keras-tcn  -i https://mirrors.aliyun.com/pypi/simple/

# %%
# 将日期列转换为datetime类型
merged_df['date'] = pd.to_datetime(merged_df['date'])

# 定义特征列
features = ['ndci', 'ndvi', 'evi', 'FAI', 'nrfi', 'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7',
           'GMT_0000_PAR', 'GMT_0300_PAR', 'GMT_0600_PAR', 'GMT_0900_PAR', 'GMT_1200_PAR',
           'GMT_1500_PAR', 'GMT_1800_PAR', 'GMT_2100_PAR', 'DAPAR', 'PDVI', 'MPAR', 'APAR',
           'PPDI', 'PAI']

# 定义目标变量
targets = ['density_mean', 'density_lower', 'density_upper']

# 计算特征和目标之间的相关性
correlations = {}
for target in targets:
    correlations[target] = {}
    for feature in features:
        corr = merged_df[feature].corr(merged_df[target])
        correlations[target][feature] = corr

# 为每个目标变量打印排序后的相关性
for target in targets:
    print(f"\n{target} 与各特征的相关性排序:")
    sorted_corr = sorted(correlations[target].items(), key=lambda x: abs(x[1]), reverse=True)
    for feature, corr in sorted_corr:
        print(f"{feature}: {corr:.4f}")

# 绘制热力图
import seaborn as sns
plt.figure(figsize=(15, 10))
corr_matrix = pd.DataFrame(index=features)
for target in targets:
    corr_matrix[target] = [correlations[target][feature] for feature in features]
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('特征与目标变量的相关性热力图')
plt.tight_layout()
plt.show()
# Out:
# density_mean 与各特征的相关性排序:
# ndvi: 0.2234
# GMT_0900_PAR: 0.2196
# FAI: 0.2186
# GMT_0000_PAR: 0.1571
# GMT_1200_PAR: nan
# GMT_1500_PAR: nan
# GMT_1800_PAR: nan
# PPDI: 0.1699
# DAPAR: 0.1347
# PDVI: 0.1195
# GMT_0600_PAR: 0.1181
# GMT_0300_PAR: 0.0865
# b2: 0.0782
# b4: 0.0646
# MPAR: 0.0644
# b5: 0.0636
# b3: 0.0612
# b1: 0.0575
# nrfi: -0.0427
# GMT_2100_PAR: 0.0353
# APAR: 0.0353
# b7: -0.0319
# PAI: 0.0301
# evi: -0.0144
# b6: 0.0108
# ndci: -0.0087
#
# density_lower 与各特征的相关性排序:
# GMT_0900_PAR: 0.1645
# ndvi: 0.1590
# FAI: 0.1464
# GMT_0000_PAR: 0.1224
# b2: 0.0854
# GMT_1200_PAR: nan
# GMT_1500_PAR: nan
# GMT_1800_PAR: nan
# PPDI: 0.1441
# DAPAR: 0.0981
# PDVI: 0.0864
# GMT_0600_PAR: 0.0801
# b4: 0.0777
# b3: 0.0749
# b5: 0.0742
# b1: 0.0729
# GMT_0300_PAR: 0.0628
# ndci: -0.0538
# MPAR: 0.0428
# b6: 0.0346
# nrfi: 0.0161
# PAI: -0.0134
# b7: -0.0041
# evi: 0.0028
# GMT_2100_PAR: -0.0009
# APAR: -0.0009
#
# density_upper 与各特征的相关性排序:
# FAI: 0.2446
# ndvi: 0.2432
# GMT_0900_PAR: 0.2428
# GMT_0000_PAR: 0.1696
# nrfi: -0.0821
# GMT_1200_PAR: nan
# GMT_1500_PAR: nan
# GMT_1800_PAR: nan
# PPDI: 0.1745
# DAPAR: 0.1499
# GMT_0600_PAR: 0.1353
# PDVI: 0.1324
# GMT_0300_PAR: 0.0959
# MPAR: 0.0724
# b2: 0.0670
# PAI: 0.0564
# GMT_2100_PAR: 0.0562
# APAR: 0.0562
# b7: -0.0514
# b4: 0.0510
# b5: 0.0508
# b3: 0.0472
# b1: 0.0430
# ndci: 0.0280
# evi: -0.0242
# b6: -0.0086
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 26631 (\N{CJK UNIFIED IDEOGRAPH-6807}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1750480707.py:36: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from current font.
#   plt.tight_layout()
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 19982 (\N{CJK UNIFIED IDEOGRAPH-4E0E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30446 (\N{CJK UNIFIED IDEOGRAPH-76EE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26631 (\N{CJK UNIFIED IDEOGRAPH-6807}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 37327 (\N{CJK UNIFIED IDEOGRAPH-91CF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 将日期列转换为datetime类型
merged_df['date'] = pd.to_datetime(merged_df['date'])

# 定义特征列和目标变量
features = ['ndci', 'ndvi', 'evi', 'FAI', 'nrfi', 'b1', 'b2', 'b3', 'b4', 'b5', 'b6', 'b7',
           'GMT_0000_PAR', 'GMT_0300_PAR', 'GMT_0600_PAR', 'GMT_0900_PAR', 'GMT_1200_PAR',
           'GMT_1500_PAR', 'GMT_1800_PAR', 'GMT_2100_PAR', 'DAPAR', 'PDVI', 'MPAR', 'APAR',
           'PPDI', 'PAI']
targets = ['density_mean', 'density_lower', 'density_upper']

# 计算1-15天滞后相关性
max_lag = 15
lag_correlations = {}

for target in targets:
    lag_correlations[target] = {}
    for feature in features:
        lag_correlations[target][feature] = []
        for lag in range(1, max_lag + 1):
            # 创建滞后特征序列
            lagged_feature = merged_df[feature].shift(-lag)  # 负滞后表示特征值对未来目标的影响
            # 计算相关性
            corr = lagged_feature.corr(merged_df[target])
            lag_correlations[target][feature].append(corr)

# 绘制滞后相关性热力图
import seaborn as sns
import numpy as np

for target in targets:
    plt.figure(figsize=(15, 10))
    # 将相关系数转换为numpy数组以确保数据类型为float
    lag_data = np.array([[lag_correlations[target][feature][i] for i in range(max_lag)] for feature in features])
    lag_matrix = pd.DataFrame(lag_data, 
                            index=features,
                            columns=[f'Lag_{i+1}' for i in range(max_lag)])
    
    sns.heatmap(lag_matrix, annot=True, cmap='coolwarm', center=0, fmt='.2f')
    plt.title(f'{target}的1-15天滞后相关性热力图')
    plt.xlabel('滞后天数')
    plt.ylabel('特征')
    plt.tight_layout()
    plt.show()

    # 打印每个特征的最大相关性及其对应的滞后天数
    print(f"\n{target}的最大滞后相关性:")
    for feature in features:
        corrs = lag_correlations[target][feature]
        max_corr = max(corrs, key=abs)
        max_lag_day = corrs.index(max_corr) + 1
        print(f"{feature}: 最大相关系数 = {max_corr:.4f} (滞后{max_lag_day}天)")
# Out:
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 28382 (\N{CJK UNIFIED IDEOGRAPH-6EDE}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from current font.
#   plt.tight_layout()
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 28382 (\N{CJK UNIFIED IDEOGRAPH-6EDE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# density_mean的最大滞后相关性:
# ndci: 最大相关系数 = -0.0424 (滞后4天)
# ndvi: 最大相关系数 = 0.2154 (滞后1天)
# evi: 最大相关系数 = -0.0371 (滞后1天)
# FAI: 最大相关系数 = 0.2035 (滞后1天)
# nrfi: 最大相关系数 = -0.0271 (滞后2天)
# b1: 最大相关系数 = 0.0649 (滞后1天)
# b2: 最大相关系数 = 0.0848 (滞后1天)
# b3: 最大相关系数 = 0.0692 (滞后1天)
# b4: 最大相关系数 = 0.0717 (滞后1天)
# b5: 最大相关系数 = 0.0734 (滞后1天)
# b6: 最大相关系数 = 0.0291 (滞后3天)
# b7: 最大相关系数 = -0.0404 (滞后14天)
# GMT_0000_PAR: 最大相关系数 = 0.1816 (滞后7天)
# GMT_0300_PAR: 最大相关系数 = 0.1071 (滞后15天)
# GMT_0600_PAR: 最大相关系数 = 0.1085 (滞后6天)
# GMT_0900_PAR: 最大相关系数 = 0.2182 (滞后6天)
# GMT_1200_PAR: 最大相关系数 = nan (滞后1天)
# GMT_1500_PAR: 最大相关系数 = nan (滞后1天)
# GMT_1800_PAR: 最大相关系数 = nan (滞后1天)
# GMT_2100_PAR: 最大相关系数 = 0.0499 (滞后15天)
# DAPAR: 最大相关系数 = 0.1410 (滞后7天)
# PDVI: 最大相关系数 = 0.1297 (滞后15天)
# MPAR: 最大相关系数 = 0.0898 (滞后15天)
# APAR: 最大相关系数 = 0.0499 (滞后15天)
# PPDI: 最大相关系数 = 0.1742 (滞后1天)
# PAI: 最大相关系数 = 0.0683 (滞后15天)
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 28382 (\N{CJK UNIFIED IDEOGRAPH-6EDE}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from current font.
#   plt.tight_layout()
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 28382 (\N{CJK UNIFIED IDEOGRAPH-6EDE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# density_lower的最大滞后相关性:
# ndci: 最大相关系数 = -0.0548 (滞后1天)
# ndvi: 最大相关系数 = 0.1535 (滞后1天)
# evi: 最大相关系数 = 0.0461 (滞后11天)
# FAI: 最大相关系数 = 0.1390 (滞后1天)
# nrfi: 最大相关系数 = 0.0193 (滞后10天)
# b1: 最大相关系数 = 0.0713 (滞后1天)
# b2: 最大相关系数 = 0.0837 (滞后1天)
# b3: 最大相关系数 = 0.0741 (滞后1天)
# b4: 最大相关系数 = 0.0762 (滞后1天)
# b5: 最大相关系数 = 0.0726 (滞后1天)
# b6: 最大相关系数 = 0.0348 (滞后1天)
# b7: 最大相关系数 = -0.0367 (滞后11天)
# GMT_0000_PAR: 最大相关系数 = 0.1547 (滞后14天)
# GMT_0300_PAR: 最大相关系数 = 0.0910 (滞后15天)
# GMT_0600_PAR: 最大相关系数 = 0.0918 (滞后6天)
# GMT_0900_PAR: 最大相关系数 = 0.1839 (滞后6天)
# GMT_1200_PAR: 最大相关系数 = nan (滞后1天)
# GMT_1500_PAR: 最大相关系数 = nan (滞后1天)
# GMT_1800_PAR: 最大相关系数 = nan (滞后1天)
# GMT_2100_PAR: 最大相关系数 = -0.0207 (滞后5天)
# DAPAR: 最大相关系数 = 0.1197 (滞后6天)
# PDVI: 最大相关系数 = 0.1110 (滞后15天)
# MPAR: 最大相关系数 = 0.0778 (滞后15天)
# APAR: 最大相关系数 = -0.0207 (滞后5天)
# PPDI: 最大相关系数 = 0.1540 (滞后13天)
# PAI: 最大相关系数 = -0.0151 (滞后5天)
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 28382 (\N{CJK UNIFIED IDEOGRAPH-6EDE}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_30153/1156346976.py:42: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from current font.
#   plt.tight_layout()
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 29305 (\N{CJK UNIFIED IDEOGRAPH-7279}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24449 (\N{CJK UNIFIED IDEOGRAPH-5F81}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22825 (\N{CJK UNIFIED IDEOGRAPH-5929}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 28382 (\N{CJK UNIFIED IDEOGRAPH-6EDE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30456 (\N{CJK UNIFIED IDEOGRAPH-76F8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20851 (\N{CJK UNIFIED IDEOGRAPH-5173}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 28909 (\N{CJK UNIFIED IDEOGRAPH-70ED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21147 (\N{CJK UNIFIED IDEOGRAPH-529B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25968 (\N{CJK UNIFIED IDEOGRAPH-6570}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# density_upper的最大滞后相关性:
# ndci: 最大相关系数 = 0.0434 (滞后15天)
# ndvi: 最大相关系数 = 0.2342 (滞后1天)
# evi: 最大相关系数 = -0.0363 (滞后1天)
# FAI: 最大相关系数 = 0.2270 (滞后1天)
# nrfi: 最大相关系数 = -0.0569 (滞后2天)
# b1: 最大相关系数 = 0.0561 (滞后3天)
# b2: 最大相关系数 = 0.0794 (滞后3天)
# b3: 最大相关系数 = 0.0630 (滞后3天)
# b4: 最大相关系数 = 0.0638 (滞后3天)
# b5: 最大相关系数 = 0.0710 (滞后3天)
# b6: 最大相关系数 = 0.0271 (滞后3天)
# b7: 最大相关系数 = -0.0491 (滞后6天)
# GMT_0000_PAR: 最大相关系数 = 0.1921 (滞后7天)
# GMT_0300_PAR: 最大相关系数 = 0.1135 (滞后14天)
# GMT_0600_PAR: 最大相关系数 = 0.1174 (滞后6天)
# GMT_0900_PAR: 最大相关系数 = 0.2321 (滞后6天)
# GMT_1200_PAR: 最大相关系数 = nan (滞后1天)
# GMT_1500_PAR: 最大相关系数 = nan (滞后1天)
# GMT_1800_PAR: 最大相关系数 = nan (滞后1天)
# GMT_2100_PAR: 最大相关系数 = 0.0800 (滞后15天)
# DAPAR: 最大相关系数 = 0.1507 (滞后7天)
# PDVI: 最大相关系数 = 0.1344 (滞后15天)
# MPAR: 最大相关系数 = 0.0923 (滞后15天)
# APAR: 最大相关系数 = 0.0800 (滞后15天)
# PPDI: 最大相关系数 = 0.1864 (滞后1天)
# PAI: 最大相关系数 = 0.1081 (滞后15天)
