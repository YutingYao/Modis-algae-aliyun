# %% [markdown]
# # density-9999不够大，无法体现差异性
#
# 要点梳理：
# - 剔除云层遮挡和数据缺失的情况
#
# 拖山的经度和纬度是(120.14,31.406)，兰山嘴的经度和纬度是(119.89,31.212)。我需要分析这2个点位逐日的叶绿素a浓度，请你修改下面的代码。如果受到云层影响导致数据缺失，请你用NAN代替。
#
# 创新点在于，将云层覆盖的区域设置为999999，这样在后续处理中可以很容易地识别出这些区域。

# %% [markdown]
# https://engine-aiearth.aliyun.com/docs/page/api?d=07f36f#heading-22
#
# https://engine-aiearth.aliyun.com/?spm=a2cvf.28031243.0.0.5dc743d42pbV5o#/utility/auth-token

# %%
import aie

aie.Authenticate(token='a883697366926140b70e960b7a5f2a5f')
aie.Initialize()
# Out:
# 计算资源初始化中，请等待...
# 计算资源初始化完成.

# %%
import geopandas as gpd

# %%
# 读取shp文件
shapefile_path = '/root/Download/Modis-algae-aliyun/local-data/taihu.shp'
gdf = gpd.read_file(shapefile_path)

# 假设shp文件中只有一个几何对象，取第一个
geometry = gdf.geometry.iloc[0]
print(geometry)
# 输出((119.95082568376117 31.341888097180494, 119.98639104240964 31.388554715968827, ...

# 将geopandas的geometry对象转换为ee.Geometry
coords = list(geometry.exterior.coords)
flattened_coords = [coord for point in coords for coord in point]
taihu = aie.Geometry.Polygon(flattened_coords)
# 构造Polygon。输入参数支持GeoJSON 'Polygon'类型格式的坐标点集，
# 同时也支持包含偶数个数字的一维List，例如aie.Geometry.Polygon([aLng, aLat, bLng, bLat, ...])。
# 需注意，输入的坐标点将以EPSG:4326坐标系进行解析。

# 打印ee.Geometry对象以验证
print(taihu)
# Out:
# POLYGON ((119.95082568376117 31.341888097180494, 119.98639104240964 31.388554715968827, 120.00611934273043 31.40820067954559, 120.0213482061359 31.420557311454473, 120.02780893606551 31.42562749019076, 120.03023170978913 31.42966374717613, 120.0274051404449 31.43596389857637, 120.02025218945138 31.447873965243872, 120.00888822698595 31.45166321445573, 120.01067646473432 31.455403102339847, 120.01448368058568 31.46224277412878, 120.01806015608244 31.467556706624215, 120.02342486932757 31.473017934057427, 120.02827041677476 31.47729813281918, 120.02902032292732 31.479561147303205, 120.03525031250228 31.481725718642263, 120.03871141782174 31.48452974796941, 120.04223020822982 31.48275879185581, 120.04678733023371 31.479659537995836, 120.05734370145801 31.476461787529658, 120.06017027080222 31.47651098451827, 120.06380443138762 31.471541958062947, 120.06276609979179 31.468442332717288, 120.06345832085567 31.46578542930369, 120.06703479635243 31.4656870240255, 120.07078432711515 31.460520601669312, 120.07280330521816 31.457765059855227, 120.07499533858713 31.456879332767407, 120.07586061491696 31.45761743925564, 120.07753348248804 31.456731710771724, 120.07851412899522 31.454025266281516, 120.07816801846326 31.44654523117508, 120.08024468165496 31.441377752890112, 120.08209060449201 31.440442654942988, 120.08278282555588 31.43916303210599, 120.08073500490855 31.4377849572039, 120.07911982242616 31.436283816843037, 120.07594714255 31.434511948104696, 120.07375510918104 31.433059975142882, 120.07193802888833 31.432813875801756, 120.07003442096264 31.430598952659206, 120.06960178279772 31.428507032753252, 120.07069779948218 31.4264396778157, 120.06965946788634 31.42412615515174, 120.06772701741635 31.42208331641407, 120.06674637090916 31.422329443920876, 120.06510234588245 31.422206380248205, 120.06308336777943 31.421517220697027, 120.06429475464124 31.419474325129915, 120.06469855026185 31.418243643673172, 120.06319873795674 31.416963717829034, 120.06247767434854 31.41639759121184, 120.06198735109493 31.414945337744186, 120.0606317515115 31.413665366895952, 120.05976647518163 31.410366899995548, 120.06190082346195 31.408643774160623, 120.0624199892599 31.407856048954017, 120.06273725724748 31.405862089971095, 120.06521771605975 31.405812855879965, 120.06596762221231 31.40445890825226, 120.06400632919794 31.400076907480816, 120.0621604063609 31.3986736392692, 120.06120860239808 31.397393446462107, 120.06103554713211 31.396187094955675, 120.05890119885183 31.393823585843574, 120.05872814358585 31.389810408052686, 120.05803592252195 31.3878406874915, 120.05898772648477 31.386043281429068, 120.05962226246002 31.382916205339846, 120.06112207476511 31.380946340183527, 120.061814295829 31.37865632001518, 120.06037216861256 31.375972246826496, 120.06469855026185 31.374790245323425, 120.06850576611323 31.37370673088287, 120.0693998849874 31.372820209774407, 120.06960178279772 31.371441160314383, 120.07182265871103 31.371096394787124, 120.07239950959759 31.36976657304778, 120.07464922805521 31.368485986180076, 120.07387047935836 31.369347921568583, 120.07433196006761 31.371761298599964, 120.07378395172537 31.372918712532815, 120.07381279426968 31.375233497629647, 120.07441848770058 31.377080359730545, 120.07248603723058 31.37836082947553, 120.07291867539551 31.380675480493956, 120.07459154296656 31.38301469751326, 120.07493765349848 31.385723191809458, 120.08061963473125 31.39399592706078, 120.08785911335771 31.40130782723652, 120.09198359719672 31.404902020535307, 120.10089594339428 31.410834600119088, 120.1032321894849 31.411400760307238, 120.1055684355755 31.41076075288613, 120.10692403515893 31.410711521365243, 120.10902954089491 31.41002227736007, 120.11015440012376 31.408840704429057, 120.1119426378721 31.40832376159299, 120.11355782035454 31.40684676636902, 120.11499994757095 31.407536033699945, 120.11621133443276 31.40795451496649, 120.11805725726981 31.407511417096718, 120.11903790377697 31.40630519562876, 120.11932632922021 31.403941 ...
# <aiearth.engine.aie_object.geometry.Geometry object at 0x7fb3d3dea0d0>

# %% [markdown]
# # 计算完整的7月份

# %% [markdown]
# 你这个逻辑还是有问题，请你用伪代码的方式，提供一个代码的逻辑框架，please think by chain-of-thought：
#
#
# 我需要你同步输出modis反演的藻密度和lanshanzui.csv'中的藻密度，使得二者之间的差距尽可能小。由于lanshanzui.csv'中的藻密度一天会产生6个值，因此lanshanzui.csv'中的藻密度将采用置信区间的形式，modis反演的藻密度将与“lanshanzui.csv'中的藻密度将采用置信区间”进行比较
#
# 请你分析并修改这段代码，我的顾虑是："""这段代码好像是通过2022年7月逐日的计算值逐步优化参数，应该根据遥感影像的sample的完整的2022年7月的结果一起计算？输出一个最终的优化参数？"""
#
# 需要你注意如下2种情况将不作为参数优化的计算依据：
# - MODIS遥感影像中藻密度为9999.0，也就是云层遮挡的情况
# - df['density']中数据缺失的情况。

# %% [markdown]
# ## demo-1.0版本-计算失败

# %%
import datetime
import csv
import aie
import pandas as pd
import numpy as np
import chardet
from datetime import timedelta
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt

# 步骤1: 数据准备
csv_file = '/root/Download/Modis-algae-aliyun/aie-taihu/00-lanshanzui.csv'

# 检测文件编码
with open(csv_file, 'rb') as f:
    result = chardet.detect(f.read())

# 使用探测到的编码读取文件
df = pd.read_csv(csv_file, encoding=result['encoding'])

# 将日期列转换为日期时间格式
df['date'] = pd.to_datetime(df['date'])

# 设置日期为索引
df.set_index('date', inplace=True)

# 对密度列进行线性插值
df['density'] = df['density'].interpolate(method='linear')

# 按日期分组并计算每日的统计数据
daily_stats = df['density'].resample('D').agg(['mean', 'std', 'count'])

# 计算95%置信区间
confidence_interval = 1.96 * daily_stats['std'] / np.sqrt(daily_stats['count'])

# 计算置信区间的上下限
daily_stats['lower_ci'] = daily_stats['mean'] - confidence_interval
daily_stats['upper_ci'] = daily_stats['mean'] + confidence_interval

# 对平均值和置信区间上下限进行线性插值
daily_stats_interpolated = daily_stats.interpolate(method='linear')

# 绘制密度和置信区间
plt.figure(figsize=(12, 6))
plt.plot(daily_stats_interpolated.index, daily_stats_interpolated['mean'], label='平均密度')
plt.fill_between(daily_stats_interpolated.index, daily_stats_interpolated['lower_ci'], daily_stats_interpolated['upper_ci'], alpha=0.2, label='95%置信区间')
plt.xlabel('日期')
plt.ylabel('密度')
plt.title('藻类密度及95%置信区间（线性插值后）')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 23494 (\N{CJK UNIFIED IDEOGRAPH-5BC6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 34299 (\N{CJK UNIFIED IDEOGRAPH-85FB}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 31867 (\N{CJK UNIFIED IDEOGRAPH-7C7B}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 21450 (\N{CJK UNIFIED IDEOGRAPH-53CA}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 32622 (\N{CJK UNIFIED IDEOGRAPH-7F6E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 32447 (\N{CJK UNIFIED IDEOGRAPH-7EBF}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 25554 (\N{CJK UNIFIED IDEOGRAPH-63D2}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/1116589033.py:55: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from current font.
#   plt.tight_layout()
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 23494 (\N{CJK UNIFIED IDEOGRAPH-5BC6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24230 (\N{CJK UNIFIED IDEOGRAPH-5EA6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 34299 (\N{CJK UNIFIED IDEOGRAPH-85FB}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 31867 (\N{CJK UNIFIED IDEOGRAPH-7C7B}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21450 (\N{CJK UNIFIED IDEOGRAPH-53CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32622 (\N{CJK UNIFIED IDEOGRAPH-7F6E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20449 (\N{CJK UNIFIED IDEOGRAPH-4FE1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21306 (\N{CJK UNIFIED IDEOGRAPH-533A}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32447 (\N{CJK UNIFIED IDEOGRAPH-7EBF}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24615 (\N{CJK UNIFIED IDEOGRAPH-6027}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 25554 (\N{CJK UNIFIED IDEOGRAPH-63D2}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20540 (\N{CJK UNIFIED IDEOGRAPH-503C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21518 (\N{CJK UNIFIED IDEOGRAPH-540E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 24179 (\N{CJK UNIFIED IDEOGRAPH-5E73}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 22343 (\N{CJK UNIFIED IDEOGRAPH-5747}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # 收集MODIS所有有效数据

# %%
roi = aie.Geometry.BBox(119.89, 31.212, 119.90, 31.222)

# %% [markdown]
# ## 加载已保存的数据版本

# %%
# 
# from requests.exceptions import ReadTimeout
# import pickle
# import datetime

# # 加载已保存的数据（如果存在）
# try:
#     current_date = datetime.date.today()
#     filename = f'saved_data_{current_date.strftime("%Y%m%d")}.pkl'
#     with open(filename, 'rb') as f:
#         saved_data = pickle.load(f)
#     valid_features = saved_data['valid_features']
#     valid_density_mean = saved_data['valid_density_mean']
#     valid_density_lower = saved_data['valid_density_lower']
#     valid_density_upper = saved_data['valid_density_upper']
#     start_date = saved_data['start_date']
#     print(f"已加载保存的数据 {filename}，从", start_date, "继续")
# except FileNotFoundError:
#     print("未找到保存的数据，从头开始")

# %% [markdown]
# ## valid_features线性插值

# %%
from aiearth.core.error.aie_error import AIEError
valid_features = {
    'ndci': [],
    'ndvi': [],
    'evi': [],
    'ndwi': [],
    'fai': [],
    'nrfi': [],
    'b1': [],
    'b2': [],
    'b3': [],
    'b4': [],
    'b5': [],
    'b6': [],
    'b7': []
}
valid_density_mean = []
valid_density_lower = []
valid_density_upper = []
start_date = datetime.date(2021, 1, 1)
end_date = datetime.date(2024, 5, 31)
delta = datetime.timedelta(days=1)
valid_dates = []

roi = aie.Geometry.BBox(119.89, 31.212, 119.90, 31.222)

def mask_clouds(image):
    qa = image.select('state_1km')
    cloud_bit_mask = 1 << 10
    mask = qa.bitwiseAnd(aie.Image.constant(cloud_bit_mask))
    return mask

while start_date <= end_date:
    date_str = start_date.strftime("%Y_%m_%d")
    retry_count = 0
    while retry_count < 10:
        try:
            img = aie.Image(f'MODIS_MOD09GA_061_{date_str}')\
                     .select(['sur_refl_b01', 'sur_refl_b02', 'sur_refl_b03', 'sur_refl_b04', 'sur_refl_b05', 'sur_refl_b06', 'sur_refl_b07', 'state_1km'])
            
            cloud_mask = mask_clouds(img)
            ndci = img.normalizedDifference(['sur_refl_b04', 'sur_refl_b03']).rename(['ndci'])
            ndvi = img.normalizedDifference(['sur_refl_b02', 'sur_refl_b01']).rename(['ndvi'])
            evi = img.expression(
                '2.5 * ((NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1))',
                {'NIR': img.select('sur_refl_b02'), 'RED': img.select('sur_refl_b01'), 'BLUE': img.select('sur_refl_b03')}
            ).rename(['evi'])
            ndwi = img.normalizedDifference(['sur_refl_b02', 'sur_refl_b05']).rename(['ndwi'])
            fai = img.expression(
                'NIR - (RED + (SWIR - RED) * (859 - 645) / (1640 - 645))',
                {
                    'NIR': img.select('sur_refl_b02'),
                    'RED': img.select('sur_refl_b01'),
                    'SWIR': img.select('sur_refl_b06')
                }
            ).rename(['fai'])
            nrfi = img.expression(
                '(RED - GREEN) / (RED + GREEN)',
                {'RED': img.select('sur_refl_b01'), 'GREEN': img.select('sur_refl_b04')}
            ).rename(['nrfi'])
            
            ndci_masked = ndci.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            ndvi_masked = ndvi.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            evi_masked = evi.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            ndwi_masked = ndwi.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            fai_masked = fai.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            nrfi_masked = nrfi.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b1_masked = img.select('sur_refl_b01').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b2_masked = img.select('sur_refl_b02').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b3_masked = img.select('sur_refl_b03').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b4_masked = img.select('sur_refl_b04').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b5_masked = img.select('sur_refl_b05').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b6_masked = img.select('sur_refl_b06').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b7_masked = img.select('sur_refl_b07').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            
            current_date = pd.to_datetime(start_date)
            if current_date in daily_stats_interpolated.index:
                mean_density = daily_stats_interpolated.loc[current_date, 'mean']
                lower_ci = daily_stats_interpolated.loc[current_date, 'lower_ci']
                upper_ci = daily_stats_interpolated.loc[current_date, 'upper_ci']
                
                ndci_values = ndci_masked.sample(roi, 100, 1, 0, True).aggregate_array('ndci').getInfo()
                ndvi_values = ndvi_masked.sample(roi, 100, 1, 0, True).aggregate_array('ndvi').getInfo()
                evi_values = evi_masked.sample(roi, 100, 1, 0, True).aggregate_array('evi').getInfo()
                ndwi_values = ndwi_masked.sample(roi, 100, 1, 0, True).aggregate_array('ndwi').getInfo()
                fai_values = fai_masked.sample(roi, 100, 1, 0, True).aggregate_array('fai').getInfo()
                nrfi_values = nrfi_masked.sample(roi, 100, 1, 0, True).aggregate_array('nrfi').getInfo()
                b1_values = b1_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b01').getInfo()
                b2_values = b2_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b02').getInfo()
                b3_values = b3_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b03').getInfo()
                b4_values = b4_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b04').getInfo()
                b5_values = b5_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b05').getInfo()
                b6_values = b6_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b06').getInfo()
                b7_values = b7_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b07').getInfo()
                
                valid_indices = [i for i in range(len(ndci_values)) if ndci_values[i] < 999999999]
                
                if valid_indices:
                    valid_features['ndci'].extend([ndci_values[i] for i in valid_indices])
                    valid_features['ndvi'].extend([ndvi_values[i] for i in valid_indices])
                    valid_features['evi'].extend([evi_values[i] for i in valid_indices])
                    valid_features['ndwi'].extend([ndwi_values[i] for i in valid_indices])
                    valid_features['fai'].extend([fai_values[i] for i in valid_indices])
                    valid_features['nrfi'].extend([nrfi_values[i] for i in valid_indices])
                    valid_features['b1'].extend([b1_values[i] for i in valid_indices])
                    valid_features['b2'].extend([b2_values[i] for i in valid_indices])
                    valid_features['b3'].extend([b3_values[i] for i in valid_indices])
                    valid_features['b4'].extend([b4_values[i] for i in valid_indices])
                    valid_features['b5'].extend([b5_values[i] for i in valid_indices])
                    valid_features['b6'].extend([b6_values[i] for i in valid_indices])
                    valid_features['b7'].extend([b7_values[i] for i in valid_indices])
                    valid_density_mean.extend([mean_density] * len(valid_indices))
                    valid_density_lower.extend([lower_ci] * len(valid_indices))
                    valid_density_upper.extend([upper_ci] * len(valid_indices))
                    valid_dates.extend([current_date] * len(valid_indices))
                   
                    # print(f"成功处理日期 {date_str} 的数据，有效样本数: {len(valid_indices)}")
                else:
                    print(f"日期 {date_str} 没有有效的样本")
            else:
                print(f"日期 {date_str} 在插值数据中不存在")
            
            break  # 如果成功处理数据，跳出重试循环
        except AIEError as e:
            print(f"处理日期 {date_str} 的数据时出错 (尝试 {retry_count + 1}/10): {str(e)}")
            retry_count += 1
            if retry_count == 10:
                print(f"无法处理日期 {date_str} 的数据，已达到最大重试次数")
    
    start_date += delta
# Out:
# 日期 2021_01_01 没有有效的样本
# 日期 2021_01_08 没有有效的样本
# 日期 2021_01_09 没有有效的样本
# 日期 2021_01_13 没有有效的样本
# 日期 2021_01_15 没有有效的样本
# 日期 2021_01_18 没有有效的样本
# 处理日期 2021_01_27 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "5f8bd134-94bb-11ef-9f62-00155d6026b0"}
# 日期 2021_01_29 没有有效的样本
# 日期 2021_01_30 没有有效的样本
# 日期 2021_02_07 没有有效的样本
# 日期 2021_02_09 没有有效的样本
# 日期 2021_02_18 没有有效的样本
# 日期 2021_02_19 没有有效的样本
# 日期 2021_02_20 没有有效的样本
# 日期 2021_02_21 没有有效的样本
# 日期 2021_03_02 没有有效的样本
# 日期 2021_03_13 没有有效的样本
# 日期 2021_03_22 没有有效的样本
# 日期 2021_03_23 没有有效的样本
# 处理日期 2021_03_26 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "a95e5d92-94c3-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "acdbea84-94c3-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "b028e84a-94c3-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "b39a136e-94c3-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "b6f44426-94c3-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "ba466a0a-94c3-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "bd856cca-94c3-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "c1a5301a-94c3-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "c5166048-94c3-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "c8af06ce-94c3-11ef-9f62-00155d6026b0"}
# 无法处理日期 2021_03_26 的数据，已达到最大重试次数
# 日期 2021_03_29 没有有效的样本
# 处理日期 2021_03_31 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "73df1386-94c4-11ef-9f62-00155d6026b0"}
# 日期 2021_04_05 没有有效的样本
# 日期 2021_04_09 没有有效的样本
# 日期 2021_04_10 没有有效的样本
# 日期 2021_04_19 没有有效的样本
# 日期 2021_04_29 没有有效的样本
# 日期 2021_04_30 没有有效的样本
# 日期 2021_05_07 没有有效的样本
# 处理日期 2021_06_01 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "d5e810ca-94cc-11ef-9f62-00155d6026b0"}
# 处理日期 2021_06_01 的数据时出错 (尝试 2/10): [AIEError]: 22820932, d956ad3e 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "d956ad3e-94cc-11ef-9f62-00155d6026b0"}
# 处理日期 2021_06_01 的数据时出错 (尝试 3/10): [AIEError]: 22820932, da138b66 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "da138b66-94cc-11ef-9f62-00155d6026b0"}
# 处理日期 2021_06_01 的数据时出错 (尝试 4/10): [AIEError]: 22820932, dade06de 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "dade06de-94cc-11ef-9f62-00155d6026b0"}
# 处理日期 2021_06_02 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "f43e5aca-94cc-11ef-9f62-00155d6026b0"}
# 日期 2021_06_06 没有有效的样本
# 处理日期 2021_06_17 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "d61aae5c-94ce-11ef-9f62-00155d6026b0"}
# 日期 2021_06_21 没有有效的样本
# 日期 2021_06_22 没有有效的样本
# 日期 2021_06_29 没有有效的样本
# 处理日期 2021_07_10 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d3b9ab6a-94d1-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d649f420-94d1-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d8ccb9e4-94d1-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "db3f6d70-94d1-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "dde0d26c-94d1-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e05c84d2-94d1-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e2fddace-94d1-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e5a3fdd0-94d1-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e81c2cc2-94d1-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ead9ef8a-94d1-11ef-9f62-00155d6026b0"}
# 无法处理日期 2021_07_10 的数据，已达到最大重试次数
# 日期 2021_07_12 没有有效的样本
# 日期 2021_07_14 没有有效的样本
# 日期 2021_07_23 没有有效的样本
# 日期 2021_07_31 没有有效的样本
# 处理日期 2021_08_06 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "6235099a-94d5-11ef-9f62-00155d6026b0"}
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1394 try:
# -> 1395     response.begin()
#    1396 except ConnectionError:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/http/client.py:294, in HTTPResponse._read_status(self)
#     291 if not line:
#     292     # Presumably, the server closed the connection before
#     293     # sending a valid response.
# --> 294     raise RemoteDisconnected("Remote end closed connection without"
#     295                              " response")
#     296 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/connectionpool.py:845, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     843     new_e = ProtocolError("Connection aborted.", new_e)
# --> 845 retries = retries.increment(
#     846     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     847 )
#     848 retries.sleep()
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/util/retry.py:470, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     469 if read is False or method is None or not self._is_method_retryable(method):
# --> 470     raise reraise(type(error), error, _stacktrace)
#     471 elif read is not None:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/util/util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1394 try:
# -> 1395     response.begin()
#    1396 except ConnectionError:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/http/client.py:294, in HTTPResponse._read_status(self)
#     291 if not line:
#     292     # Presumably, the server closed the connection before
#     293     # sending a valid response.
# --> 294     raise RemoteDisconnected("Remote end closed connection without"
#     295                              " response")
#     296 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[8], line 87
#      85 ndwi_values = ndwi_masked.sample(roi, 100, 1, 0, True).aggregate_array('ndwi').getInfo()
#      86 fai_values = fai_masked.sample(roi, 100, 1, 0, True).aggregate_array('fai').getInfo()
# ---> 87 nrfi_values = nrfi_masked.sample(roi, 100, 1, 0, True).aggregate_array('nrfi').getInfo()
#      88 b1_values = b1_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b01').getInfo()
#      89 b2_values = b2_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b02').getInfo()
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/aiearth/engine/function_node.py:18, in FunctionNode.getInfo(self)
#      17 def getInfo(self):
# ---> 18     return InteractiveSession.getInfo(self)
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/aiearth/engine/client/interactive_session.py:147, in InteractiveSession.getInfo(obj)
#     139 data = {
#     140     "taskId": task_id,
#     141     "sessionId": InteractiveSession.getCurrentSessionId(),
#     142     "script": "{\"expression\":" + expr + "}",
#     143     "options": json.dumps(options)
#     144 }
#     146 url = Endpoints.INTERACTIVE_SESSION + InteractiveSessionResource.EXEC
# --> 147 payload = InteractiveSessionClient.post(url, data)
#     149 # print("payload", json.dumps(payload))
#     151 if payload["state"] == "cancelled":
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/aiearth/engine/client/interactive_session.py:20, in InteractiveSessionClient.post(url, reqeust_data, append_extra_hdrs)
#      16 @staticmethod
#      17 def post(url, reqeust_data, append_extra_hdrs=True):
#      18     headers = {"Content-Type": "application/json"}
#      19     resp = super(InteractiveSessionClient,
# ---> 20                  InteractiveSessionClient).post(url, headers, reqeust_data, append_extra_hdrs)
#      21     response_data = resp.json()
#      23     if "code" in response_data and response_data["code"] == InteractiveSessionClient.ResponseCode.OK:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/aiearth/core/client/client.py:36, in BaseClient.post(url, hdrs, data, append_extra_hdrs)
#      32 if env.get_log_level() == g_var.LogLevel.DEBUG_LEVEL:
#      33     print(
#      34         f"BaseClient::post request. url: {url}, headers: {json.dumps(hdrs)}, data: {json.dumps(data)}")
# ---> 36 resp = requests.post(url=url, headers=hdrs, timeout=(600, 600),
#      37                      json=data, verify=False)
#      39 if resp.status_code != 200:
#      40     if "401 Authorization Required" in resp.text:
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/requests/adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# ## 网络故障继续
#
# (base) [root@N240717 Modis-algae-aliyun]# cp ~/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/connectionpool.py .
#
# (base) [root@N240717 Modis-algae-aliyun]# cp /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/urllib3/exceptions.py .

# %%
from aiearth.core.error.aie_error import AIEError
import time
from http.client import RemoteDisconnected
from requests.exceptions import ConnectionError

aie.Authenticate(token='a883697366926140b70e960b7a5f2a5f')
aie.Initialize()

valid_features = {
    'ndci': [],
    'ndvi': [],
    'evi': [],
    'ndwi': [],
    'fai': [],
    'nrfi': [],
    'b1': [],
    'b2': [],
    'b3': [],
    'b4': [],
    'b5': [],
    'b6': [],
    'b7': []
}
valid_density_mean = []
valid_density_lower = []
valid_density_upper = []
start_date = datetime.date(2021, 1, 1)
end_date = datetime.date(2024, 5, 31)
delta = datetime.timedelta(days=1)
valid_dates = []

roi = aie.Geometry.BBox(119.89, 31.212, 119.90, 31.222)

def mask_clouds(image):
    qa = image.select('state_1km')
    cloud_bit_mask = 1 << 10
    mask = qa.bitwiseAnd(aie.Image.constant(cloud_bit_mask))
    return mask

while start_date <= end_date:
    date_str = start_date.strftime("%Y_%m_%d")
    retry_count = 0
    while retry_count < 10:
        try:
            img = aie.Image(f'MODIS_MOD09GA_061_{date_str}')\
                     .select(['sur_refl_b01', 'sur_refl_b02', 'sur_refl_b03', 'sur_refl_b04', 'sur_refl_b05', 'sur_refl_b06', 'sur_refl_b07', 'state_1km'])
            
            cloud_mask = mask_clouds(img)
            ndci = img.normalizedDifference(['sur_refl_b04', 'sur_refl_b03']).rename(['ndci'])
            ndvi = img.normalizedDifference(['sur_refl_b02', 'sur_refl_b01']).rename(['ndvi'])
            evi = img.expression(
                '2.5 * ((NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1))',
                {'NIR': img.select('sur_refl_b02'), 'RED': img.select('sur_refl_b01'), 'BLUE': img.select('sur_refl_b03')}
            ).rename(['evi'])
            ndwi = img.normalizedDifference(['sur_refl_b02', 'sur_refl_b05']).rename(['ndwi'])
            fai = img.expression(
                'NIR - (RED + (SWIR - RED) * (859 - 645) / (1640 - 645))',
                {
                    'NIR': img.select('sur_refl_b02'),
                    'RED': img.select('sur_refl_b01'),
                    'SWIR': img.select('sur_refl_b06')
                }
            ).rename(['fai'])
            nrfi = img.expression(
                '(RED - GREEN) / (RED + GREEN)',
                {'RED': img.select('sur_refl_b01'), 'GREEN': img.select('sur_refl_b04')}
            ).rename(['nrfi'])
            
            ndci_masked = ndci.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            ndvi_masked = ndvi.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            evi_masked = evi.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            ndwi_masked = ndwi.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            fai_masked = fai.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            nrfi_masked = nrfi.where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b1_masked = img.select('sur_refl_b01').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b2_masked = img.select('sur_refl_b02').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b3_masked = img.select('sur_refl_b03').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b4_masked = img.select('sur_refl_b04').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b5_masked = img.select('sur_refl_b05').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b6_masked = img.select('sur_refl_b06').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            b7_masked = img.select('sur_refl_b07').where(cloud_mask.Not(), aie.Image.constant(999999999999))
            
            current_date = pd.to_datetime(start_date)
            if current_date in daily_stats_interpolated.index:
                mean_density = daily_stats_interpolated.loc[current_date, 'mean']
                lower_ci = daily_stats_interpolated.loc[current_date, 'lower_ci']
                upper_ci = daily_stats_interpolated.loc[current_date, 'upper_ci']
                
                ndci_values = ndci_masked.sample(roi, 100, 1, 0, True).aggregate_array('ndci').getInfo()
                ndvi_values = ndvi_masked.sample(roi, 100, 1, 0, True).aggregate_array('ndvi').getInfo()
                evi_values = evi_masked.sample(roi, 100, 1, 0, True).aggregate_array('evi').getInfo()
                ndwi_values = ndwi_masked.sample(roi, 100, 1, 0, True).aggregate_array('ndwi').getInfo()
                fai_values = fai_masked.sample(roi, 100, 1, 0, True).aggregate_array('fai').getInfo()
                nrfi_values = nrfi_masked.sample(roi, 100, 1, 0, True).aggregate_array('nrfi').getInfo()
                b1_values = b1_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b01').getInfo()
                b2_values = b2_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b02').getInfo()
                b3_values = b3_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b03').getInfo()
                b4_values = b4_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b04').getInfo()
                b5_values = b5_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b05').getInfo()
                b6_values = b6_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b06').getInfo()
                b7_values = b7_masked.sample(roi, 100, 1, 0, True).aggregate_array('sur_refl_b07').getInfo()
                
                valid_indices = [i for i in range(len(ndci_values)) if ndci_values[i] < 999999999]
                
                if valid_indices:
                    valid_features['ndci'].extend([ndci_values[i] for i in valid_indices])
                    valid_features['ndvi'].extend([ndvi_values[i] for i in valid_indices])
                    valid_features['evi'].extend([evi_values[i] for i in valid_indices])
                    valid_features['ndwi'].extend([ndwi_values[i] for i in valid_indices])
                    valid_features['fai'].extend([fai_values[i] for i in valid_indices])
                    valid_features['nrfi'].extend([nrfi_values[i] for i in valid_indices])
                    valid_features['b1'].extend([b1_values[i] for i in valid_indices])
                    valid_features['b2'].extend([b2_values[i] for i in valid_indices])
                    valid_features['b3'].extend([b3_values[i] for i in valid_indices])
                    valid_features['b4'].extend([b4_values[i] for i in valid_indices])
                    valid_features['b5'].extend([b5_values[i] for i in valid_indices])
                    valid_features['b6'].extend([b6_values[i] for i in valid_indices])
                    valid_features['b7'].extend([b7_values[i] for i in valid_indices])
                    valid_density_mean.extend([mean_density] * len(valid_indices))
                    valid_density_lower.extend([lower_ci] * len(valid_indices))
                    valid_density_upper.extend([upper_ci] * len(valid_indices))
                    valid_dates.extend([current_date] * len(valid_indices))
                   
                    # print(f"成功处理日期 {date_str} 的数据，有效样本数: {len(valid_indices)}")
                else:
                    print(f"日期 {date_str} 没有有效的样本")
            else:
                print(f"日期 {date_str} 在插值数据中不存在")
            
            break  # 如果成功处理数据，跳出重试循环
        except (AIEError, RemoteDisconnected, ConnectionError) as e:
            print(f"处理日期 {date_str} 的数据时出错 (尝试 {retry_count + 1}/10): {str(e)}")
            retry_count += 1
            if retry_count < 10:
                time.sleep(5)  # 等待5秒后重试
            elif retry_count == 10:
                print(f"无法处理日期 {date_str} 的数据，已达到最大重试次数")
    
    start_date += delta
# Out:
# 计算资源初始化中，请等待...
# 计算资源初始化完成.
# 日期 2021_01_01 没有有效的样本
# 日期 2021_01_08 没有有效的样本
# 日期 2021_01_09 没有有效的样本
# 日期 2021_01_13 没有有效的样本
# 日期 2021_01_15 没有有效的样本
# 日期 2021_01_18 没有有效的样本
# 日期 2021_01_29 没有有效的样本
# 日期 2021_01_30 没有有效的样本
# 日期 2021_02_07 没有有效的样本
# 日期 2021_02_09 没有有效的样本
# 日期 2021_02_18 没有有效的样本
# 日期 2021_02_19 没有有效的样本
# 日期 2021_02_20 没有有效的样本
# 日期 2021_02_21 没有有效的样本
# 日期 2021_03_02 没有有效的样本
# 处理日期 2021_03_13 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "c47c6940-951b-11ef-9f62-00155d6026b0"}
# 日期 2021_03_13 没有有效的样本
# 日期 2021_03_22 没有有效的样本
# 日期 2021_03_23 没有有效的样本
# 处理日期 2021_03_26 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "8cc0028a-951d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "92f3b368-951d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "98dfed00-951d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "9efbde7e-951d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "a57d06ec-951d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "abf20aea-951d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "b27a0b42-951d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "b99d9cea-951d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "c0897c7c-951d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_03_26 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "c67e9b26-951d-11ef-9f62-00155d6026b0"}
# 无法处理日期 2021_03_26 的数据，已达到最大重试次数
# 日期 2021_03_29 没有有效的样本
# 日期 2021_04_05 没有有效的样本
# 日期 2021_04_09 没有有效的样本
# 日期 2021_04_10 没有有效的样本
# 日期 2021_04_19 没有有效的样本
# 日期 2021_04_29 没有有效的样本
# 日期 2021_04_30 没有有效的样本
# 日期 2021_05_07 没有有效的样本
# 处理日期 2021_05_22 的数据时出错 (尝试 1/10): [AIEError]: 22820932, dcc0cdd0 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "dcc0cdd0-9524-11ef-9f62-00155d6026b0"}
# 日期 2021_06_06 没有有效的样本
# 日期 2021_06_21 没有有效的样本
# 日期 2021_06_22 没有有效的样本
# 日期 2021_06_29 没有有效的样本
# 处理日期 2021_07_10 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9ebb34f2-952a-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a43e14e4-952a-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a96c1b82-952a-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ae9a50f6-952a-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b401d294-952a-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b9c318aa-952a-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "bf19388e-952a-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c49171fa-952a-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ca062cde-952a-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_10 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "cf691088-952a-11ef-9f62-00155d6026b0"}
# 无法处理日期 2021_07_10 的数据，已达到最大重试次数
# 日期 2021_07_12 没有有效的样本
# 日期 2021_07_14 没有有效的样本
# 日期 2021_07_23 没有有效的样本
# 处理日期 2021_07_25 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "89d1aef2-952c-11ef-9f62-00155d6026b0"}
# 处理日期 2021_07_25 的数据时出错 (尝试 2/10): [AIEError]: 22820932, 8fd924b0 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "8fd924b0-952c-11ef-9f62-00155d6026b0"}
# 日期 2021_07_31 没有有效的样本
# 日期 2021_08_06 没有有效的样本
# 日期 2021_08_07 没有有效的样本
# 处理日期 2021_08_08 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "513c61f2-952e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_08_08 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "57479fb2-952e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_08_08 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "5d57619e-952e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_08_08 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "6366e5d2-952e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_08_08 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "69b2e60c-952e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_08_08 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "70000184-952e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_08_08 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "75cb0a3c-952e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_08_08 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "7ca62116-952e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_08_08 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "829b8f7a-952e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_08_08 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "8889cc08-952e-11ef-9f62-00155d6026b0"}
# 无法处理日期 2021_08_08 的数据，已达到最大重试次数
# 日期 2021_08_09 没有有效的样本
# 日期 2021_08_19 没有有效的样本
# 日期 2021_08_25 没有有效的样本
# 日期 2021_08_31 没有有效的样本
# 日期 2021_09_01 没有有效的样本
# 日期 2021_09_09 没有有效的样本
# 处理日期 2021_09_21 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "1a11ddb4-9534-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_21 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "200a0fa2-9534-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_21 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "260b0ff0-9534-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_21 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "2c083fb8-9534-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_21 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "3207c4a6-9534-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_21 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "387a0312-9534-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_21 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "3ec87d66-9534-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_21 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "45530174-9534-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_21 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "4b9a64be-9534-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_21 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "51c9e396-9534-11ef-9f62-00155d6026b0"}
# 无法处理日期 2021_09_21 的数据，已达到最大重试次数
# 日期 2021_09_22 没有有效的样本
# 日期 2021_09_23 没有有效的样本
# 处理日期 2021_09_27 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "15172296-9535-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_27 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "1b384fe2-9535-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_27 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "21392e20-9535-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_27 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "2757d3ce-9535-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_27 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "2d8ac86e-9535-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_27 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "337938be-9535-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_27 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "398f5f4e-9535-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_27 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "402ff412-9535-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_27 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "46c86c46-9535-11ef-9f62-00155d6026b0"}
# 处理日期 2021_09_27 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "4d39861e-9535-11ef-9f62-00155d6026b0"}
# 无法处理日期 2021_09_27 的数据，已达到最大重试次数
# 处理日期 2021_09_30 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "9c6d1b4c-9535-11ef-9f62-00155d6026b0"}
# 日期 2021_09_30 没有有效的样本
# 日期 2021_10_04 没有有效的样本
# 日期 2021_10_05 没有有效的样本
# 处理日期 2021_10_10 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "02d21044-9537-11ef-9f62-00155d6026b0"}
# 日期 2021_10_10 没有有效的样本
# 日期 2021_10_23 没有有效的样本
# 日期 2021_10_24 没有有效的样本
# 日期 2021_10_26 没有有效的样本
# 日期 2021_10_27 没有有效的样本
# 日期 2021_10_28 没有有效的样本
# 日期 2021_10_30 没有有效的样本
# 日期 2021_10_31 没有有效的样本
# 日期 2021_11_01 没有有效的样本
# 处理日期 2021_11_06 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "81cbe76e-953a-11ef-9f62-00155d6026b0"}
# 日期 2021_11_08 没有有效的样本
# 日期 2021_11_09 没有有效的样本
# 日期 2021_11_10 没有有效的样本
# 处理日期 2021_11_11 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "2dc8a64c-953b-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_11 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "33e5dcb6-953b-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_11 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "399258b0-953b-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_11 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "3f71bbcc-953b-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_11 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "455c7892-953b-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_11 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "4bbac964-953b-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_11 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "51e94df6-953b-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_11 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "58f9472c-953b-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_11 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "5efc536c-953b-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_11 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "650b1c34-953b-11ef-9f62-00155d6026b0"}
# 无法处理日期 2021_11_11 的数据，已达到最大重试次数
# 日期 2021_11_14 没有有效的样本
# 日期 2021_11_15 没有有效的样本
# 处理日期 2021_11_24 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "0365ceaa-953d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_24 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "0a14ece0-953d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_24 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "10403322-953d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_24 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "1648f632-953d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_24 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "1c67980c-953d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_24 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "229b4822-953d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_24 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "28a83aae-953d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_24 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "2f469f72-953d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_24 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "354c793c-953d-11ef-9f62-00155d6026b0"}
# 处理日期 2021_11_24 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:sur_refl_b07,存在的属性有:[]. {"taskId": "3b26d76c-953d-11ef-9f62-00155d6026b0"}
# 无法处理日期 2021_11_24 的数据，已达到最大重试次数
# 日期 2021_11_27 没有有效的样本
# 日期 2021_11_30 没有有效的样本
# 日期 2021_12_01 没有有效的样本
# 日期 2021_12_03 没有有效的样本
# 日期 2021_12_05 没有有效的样本
# 处理日期 2021_12_06 的数据时出错 (尝试 1/10): [AIEError]: 22820932, b41aa6c0 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "b41aa6c0-953e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_06 的数据时出错 (尝试 2/10): [AIEError]: 22820932, b8567f16 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "b8567f16-953e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_06 的数据时出错 (尝试 3/10): [AIEError]: 22820932, bc3ad7e4 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "bc3ad7e4-953e-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_06 的数据时出错 (尝试 4/10): [AIEError]: 22820932, c010eaac 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "c010eaac-953e-11ef-9f62-00155d6026b0"}
# 日期 2021_12_07 没有有效的样本
# 日期 2021_12_13 没有有效的样本
# 处理日期 2021_12_17 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "10007f86-9540-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_17 的数据时出错 (尝试 2/10): [AIEError]: 22820932, 15cc319e 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "15cc319e-9540-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_17 的数据时出错 (尝试 3/10): [AIEError]: 22820932, 19d9f384 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "19d9f384-9540-11ef-9f62-00155d6026b0"}
# 日期 2021_12_17 没有有效的样本
# 日期 2021_12_19 没有有效的样本
# 日期 2021_12_20 没有有效的样本
# 日期 2021_12_23 没有有效的样本
# 日期 2021_12_26 没有有效的样本
# 日期 2021_12_27 没有有效的样本
# 处理日期 2021_12_28 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "501cee0a-9541-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_28 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "559329ee-9541-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_28 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "5af24528-9541-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_28 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6029a32e-9541-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_28 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "65738bc4-9541-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_28 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6aa20c60-9541-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_28 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "700aef3c-9541-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_28 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "753fba5a-9541-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_28 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "7a88e432-9541-11ef-9f62-00155d6026b0"}
# 处理日期 2021_12_28 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "800855f0-9541-11ef-9f62-00155d6026b0"}
# 无法处理日期 2021_12_28 的数据，已达到最大重试次数
# 日期 2022_01_02 没有有效的样本
# 处理日期 2022_01_03 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "19290df6-9542-11ef-9f62-00155d6026b0"}
# 处理日期 2022_01_03 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1e9a6fd2-9542-11ef-9f62-00155d6026b0"}
# 处理日期 2022_01_03 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "23ef9d9a-9542-11ef-9f62-00155d6026b0"}
# 处理日期 2022_01_03 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2933c088-9542-11ef-9f62-00155d6026b0"}
# 处理日期 2022_01_03 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2e7b0a74-9542-11ef-9f62-00155d6026b0"}
# 处理日期 2022_01_03 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "33b5a4a4-9542-11ef-9f62-00155d6026b0"}
# 处理日期 2022_01_03 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "39270b8a-9542-11ef-9f62-00155d6026b0"}
# 处理日期 2022_01_03 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "3e831c4a-9542-11ef-9f62-00155d6026b0"}
# 处理日期 2022_01_03 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "43caf6fa-9542-11ef-9f62-00155d6026b0"}
# 处理日期 2022_01_03 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "4938261c-9542-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_01_03 的数据，已达到最大重试次数
# 日期 2022_01_11 没有有效的样本
# 处理日期 2022_01_14 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "96a7f0a2-9543-11ef-9f62-00155d6026b0"}
# 日期 2022_01_18 没有有效的样本
# 日期 2022_01_30 没有有效的样本
# 日期 2022_02_05 没有有效的样本
# 日期 2022_02_14 没有有效的样本
# 处理日期 2022_02_17 的数据时出错 (尝试 1/10): [AIEError]: 22820932, c82a51ca 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "c82a51ca-9547-11ef-9f62-00155d6026b0"}
# 处理日期 2022_02_17 的数据时出错 (尝试 2/10): [AIEError]: 22820932, cbd5043c 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "cbd5043c-9547-11ef-9f62-00155d6026b0"}
# 处理日期 2022_02_17 的数据时出错 (尝试 3/10): [AIEError]: 22820932, cf7e4440 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "cf7e4440-9547-11ef-9f62-00155d6026b0"}
# 处理日期 2022_02_17 的数据时出错 (尝试 4/10): [AIEError]: 22820932, d3315fa0 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "d3315fa0-9547-11ef-9f62-00155d6026b0"}
# 处理日期 2022_02_17 的数据时出错 (尝试 5/10): [AIEError]: 22820932, d733c548 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "d733c548-9547-11ef-9f62-00155d6026b0"}
# 处理日期 2022_02_17 的数据时出错 (尝试 6/10): [AIEError]: 22820932, dae80460 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "dae80460-9547-11ef-9f62-00155d6026b0"}
# 处理日期 2022_02_17 的数据时出错 (尝试 7/10): [AIEError]: 22820932, de8e3c38 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "de8e3c38-9547-11ef-9f62-00155d6026b0"}
# 处理日期 2022_02_17 的数据时出错 (尝试 8/10): [AIEError]: 22820932, e232b742 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "e232b742-9547-11ef-9f62-00155d6026b0"}
# 处理日期 2022_02_17 的数据时出错 (尝试 9/10): [AIEError]: 22820932, e6d0a9b2 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "e6d0a9b2-9547-11ef-9f62-00155d6026b0"}
# 处理日期 2022_02_17 的数据时出错 (尝试 10/10): [AIEError]: 22820932, ea804266 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "ea804266-9547-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_02_17 的数据，已达到最大重试次数
# 处理日期 2022_02_18 的数据时出错 (尝试 1/10): [AIEError]: 22820932, ea90468e 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "ea90468e-9547-11ef-9f62-00155d6026b0"}
# 日期 2022_02_21 没有有效的样本
# 处理日期 2022_02_22 的数据时出错 (尝试 1/10): [AIEError]: 22820932, 7acfb73e 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "7acfb73e-9548-11ef-9f62-00155d6026b0"}
# 日期 2022_02_23 没有有效的样本
# 日期 2022_02_24 没有有效的样本
# 日期 2022_02_25 没有有效的样本
# 日期 2022_02_26 没有有效的样本
# 处理日期 2022_02_27 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "2b84e450-9549-11ef-9f62-00155d6026b0"}
# 日期 2022_02_28 没有有效的样本
# 日期 2022_03_01 没有有效的样本
# 日期 2022_03_04 没有有效的样本
# 日期 2022_03_07 没有有效的样本
# 日期 2022_03_09 没有有效的样本
# 日期 2022_03_12 没有有效的样本
# 日期 2022_03_23 没有有效的样本
# 日期 2022_04_02 没有有效的样本
# 日期 2022_04_03 没有有效的样本
# 日期 2022_04_06 没有有效的样本
# 日期 2022_04_07 没有有效的样本
# 日期 2022_04_08 没有有效的样本
# 处理日期 2022_04_09 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "7a7f76c4-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_09 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8020f724-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_09 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "859b0316-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_09 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8b09a898-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_09 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "90c11618-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_09 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9621a910-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_09 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9b834f44-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_09 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a10a3a72-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_09 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a66368e0-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_09 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "abca30c0-954e-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_04_09 的数据，已达到最大重试次数
# 日期 2022_04_11 没有有效的样本
# 处理日期 2022_04_12 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "eb737db2-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_12 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f0e02818-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_12 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f62400ec-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_12 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "fb9bade0-954e-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_12 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "00dffe3c-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_12 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "06443230-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_12 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "0ba04778-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_12 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1115eb18-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_12 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "16d23502-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_12 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1c433270-954f-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_04_12 的数据，已达到最大重试次数
# 处理日期 2022_04_13 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1e8770c8-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_13 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "23fa5d4a-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_13 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2951d048-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_13 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2eaf5808-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_13 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "34116192-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_13 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "3982e9fc-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_13 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "3f208900-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_13 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "447d7764-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_13 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "4a0213c0-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_13 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "4fb57870-954f-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_04_13 的数据，已达到最大重试次数
# 处理日期 2022_04_16 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "905b7d84-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_16 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "95cde0d6-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_16 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9b0fce1a-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_16 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a0848ef8-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_16 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a5dc3522-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_16 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ab2676b4-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_16 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b0713294-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_16 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b5db511a-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_16 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "bb64aad2-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_16 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c0cd95ba-954f-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_04_16 的数据，已达到最大重试次数
# 日期 2022_04_17 没有有效的样本
# 处理日期 2022_04_18 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e22578fe-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_18 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e7b054ba-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_18 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ed2f894c-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_18 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f2731716-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_18 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f7f24d56-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_18 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "fd3e089a-954f-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_18 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "028ac22a-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_18 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "08028922-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_18 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "0d6912be-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_18 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "12c10186-9550-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_04_18 的数据，已达到最大重试次数
# 处理日期 2022_04_19 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "15198016-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_19 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1ab57462-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_19 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1fe92eba-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_19 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "25143952-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_19 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2a5b0292-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_19 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2fa98a84-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_19 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "352e48e6-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_19 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "3a7ea1d8-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_19 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "400761c6-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_19 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "45c9042a-9550-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_04_19 的数据，已达到最大重试次数
# 处理日期 2022_04_22 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "87efd3f6-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_22 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8d567494-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_22 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "92f5e9f2-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_22 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9879a4fe-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_22 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9de8201e-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_22 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a3a6cd16-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_22 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a90fdd88-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_22 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ae7580e8-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_22 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b3f8ca8e-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_22 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b94e4da6-9550-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_04_22 的数据，已达到最大重试次数
# 处理日期 2022_04_23 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "bba382ba-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_23 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c10644ae-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_23 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c6897130-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_23 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "cbec2f5a-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_23 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d150523c-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_23 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d69c0ace-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_23 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "dc03b958-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_23 的数据时出错 (尝试 8/10): [AIEError]: 22820932, e1b64938 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "e1b64938-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_23 的数据时出错 (尝试 9/10): [AIEError]: 22820932, e4d96e6a 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "e4d96e6a-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_23 的数据时出错 (尝试 10/10): [AIEError]: 22820932, e7e62fb2 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "e7e62fb2-9550-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_04_23 的数据，已达到最大重试次数
# 处理日期 2022_04_24 的数据时出错 (尝试 1/10): [AIEError]: 22820932, e7f47ffe 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "e7f47ffe-9550-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_26 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2b5aa084-9551-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_26 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "30e0ca6a-9551-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_26 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "36325038-9551-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_26 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "3b881f40-9551-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_26 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "40cc41f2-9551-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_26 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "4615e74e-9551-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_26 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "4b8088ce-9551-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_26 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "50dd9046-9551-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_26 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "56415090-9551-11ef-9f62-00155d6026b0"}
# 处理日期 2022_04_26 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "5ba32838-9551-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_04_26 的数据，已达到最大重试次数
# 处理日期 2022_05_03 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "19713d64-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_03 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1efd48cc-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_03 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2495f7a2-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_03 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "29df8df4-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_03 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2f4938d0-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_03 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "34e7a650-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_03 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "3a5eda0e-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_03 的数据时出错 (尝试 8/10): 系统未知异常. {"taskId": "3fd369dc-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_03 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "4544c99c-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_03 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "4bed2438-9552-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_03 的数据，已达到最大重试次数
# 日期 2022_05_04 没有有效的样本
# 处理日期 2022_05_05 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6dae8184-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_05 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "7327cd6e-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_05 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "7857ba1a-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_05 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "7d96d0a6-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_05 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "82e32e38-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_05 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "88487e5a-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_05 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8d8c25a6-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_05 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "92d7a058-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_05 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "984c7cd4-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_05 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9d7b0ab8-9552-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_05 的数据，已达到最大重试次数
# 处理日期 2022_05_06 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9fa8ebac-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_06 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a5339086-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_06 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "aa7b633e-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_06 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "aff24e04-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_06 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b53414f6-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_06 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "baa58aa0-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_06 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c00a813a-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_06 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c578b39e-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_06 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "cac52cb0-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_06 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d0107a80-9552-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_06 的数据，已达到最大重试次数
# 处理日期 2022_05_07 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d292d5dc-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_07 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d805cc4a-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_07 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "dd83fe30-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_07 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e2c1d570-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_07 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e8473e4a-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_07 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "eda5a9c6-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_07 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f2df2624-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_07 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f817cf42-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_07 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "fd864166-9552-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_07 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "02ebbd16-9553-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_07 的数据，已达到最大重试次数
# 日期 2022_05_08 没有有效的样本
# 日期 2022_05_09 没有有效的样本
# 处理日期 2022_05_11 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "5e7dad1a-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_11 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "63d44f12-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_11 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6902cf0e-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_11 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6e3d5ebc-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_11 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "737f2ff4-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_11 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "78de66a4-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_11 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "7e1f87e2-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_11 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "83776eb2-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_11 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "88f563f8-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_11 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8e397f70-9553-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_11 的数据，已达到最大重试次数
# 处理日期 2022_05_13 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ae1e093c-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_13 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b37a9c9c-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_13 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b8a41bc6-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_13 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "be112162-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_13 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c340c37c-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_13 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c88c010c-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_13 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "cdb7b5cc-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_13 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d323a354-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_13 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d872a3fa-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_13 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ddc05640-9553-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_13 的数据，已达到最大重试次数
# 处理日期 2022_05_14 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "dffc2dee-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_14 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e5946690-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_14 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "eacb81ca-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_14 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f00744bc-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_14 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f5611064-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_14 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "faac0858-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_14 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "fffe9f32-9553-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_14 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "05266d50-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_14 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "0a90dd52-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_14 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "0fd943f8-9554-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_14 的数据，已达到最大重试次数
# 处理日期 2022_05_15 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "12390cdc-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_15 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "179e06c8-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_15 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1cf7bb64-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_15 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "223434cc-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_15 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "27720248-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_15 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2ce6b3ae-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_15 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "3218f4ea-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_15 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "376068b6-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_15 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "3c89d2f0-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_15 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "41eea964-9554-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_15 的数据，已达到最大重试次数
# 处理日期 2022_05_16 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "44237408-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_16 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "499b0d24-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_16 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "4eda2cb6-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_16 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "54479058-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_16 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "597bf05a-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_16 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "5eb89488-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_16 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6425fb72-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_16 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "69599dce-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_16 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6e9410b2-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_16 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "73cf6158-9554-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_16 的数据，已达到最大重试次数
# 处理日期 2022_05_17 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "763980b8-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_17 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "7b90c9c2-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_17 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "80dad0bc-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_17 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8608556e-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_17 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8b6c7350-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_17 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "90ae2f98-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_17 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "961d0e90-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_17 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9b90f97c-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_17 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a0d5aaa4-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_17 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a616d880-9554-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_17 的数据，已达到最大重试次数
# 处理日期 2022_05_18 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a8673210-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_18 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "adcb77de-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_18 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b2e3e120-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_18 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b8651222-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_18 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "bdb6412e-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_18 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c2fea950-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_18 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c8263038-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_18 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "cdad44a6-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_18 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d2f864ae-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_18 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d83f83d4-9554-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_18 的数据，已达到最大重试次数
# 处理日期 2022_05_19 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "dab6c258-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_19 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e0062ec4-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_19 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e5182188-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_19 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ea5e27d2-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_19 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ef845cf4-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_19 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f4a66498-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_19 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f9cc58b0-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_19 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "fefa100c-9554-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_19 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "042fbc5c-9555-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_19 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "092c6d68-9555-11ef-9f62-00155d6026b0"}
# 无法处理日期 2022_05_19 的数据，已达到最大重试次数
# 处理日期 2022_05_20 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "0b3a4292-9555-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_20 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "10a2c290-9555-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_20 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "161c9214-9555-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_20 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1b568c80-9555-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_20 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "20903886-9555-11ef-9f62-00155d6026b0"}
# 处理日期 2022_05_20 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "25cb8274-9555-11ef-9f62-00155d6026b0"}
# ...
# 处理日期 2024_03_29 的数据时出错 (尝试 4/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_29]. {"taskId": "a3ba1206-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_29 的数据时出错 (尝试 5/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_29]. {"taskId": "a6d96ebe-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_29 的数据时出错 (尝试 6/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_29]. {"taskId": "a9f1ab20-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_29 的数据时出错 (尝试 7/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_29]. {"taskId": "ad0d6c54-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_29 的数据时出错 (尝试 8/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_29]. {"taskId": "b02b4f32-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_29 的数据时出错 (尝试 9/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_29]. {"taskId": "b3455730-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_29 的数据时出错 (尝试 10/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_29]. {"taskId": "b66145e6-95ad-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_03_29 的数据，已达到最大重试次数
# 处理日期 2024_03_30 的数据时出错 (尝试 1/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_30]. {"taskId": "b6847f20-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_30 的数据时出错 (尝试 2/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_30]. {"taskId": "b9a2abfa-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_30 的数据时出错 (尝试 3/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_30]. {"taskId": "bcd3c8ea-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_30 的数据时出错 (尝试 4/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_30]. {"taskId": "bff08f90-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_30 的数据时出错 (尝试 5/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_30]. {"taskId": "c312e664-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_30 的数据时出错 (尝试 6/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_30]. {"taskId": "c62def42-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_30 的数据时出错 (尝试 7/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_30]. {"taskId": "c9478e04-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_30 的数据时出错 (尝试 8/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_30]. {"taskId": "cc64dd58-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_30 的数据时出错 (尝试 9/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_30]. {"taskId": "cf7d7e5a-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_30 的数据时出错 (尝试 10/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_03_30]. {"taskId": "d299edf8-95ad-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_03_30 的数据，已达到最大重试次数
# 处理日期 2024_03_31 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d2bac7b2-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_31 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "d85af6c4-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_31 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ddf68350-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_31 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e3939492-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_31 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "e9240ba8-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_31 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "eecad03c-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_31 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f43f9cf0-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_31 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f9cfd900-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_31 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ff6191a6-95ad-11ef-9f62-00155d6026b0"}
# 处理日期 2024_03_31 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "05128e8e-95ae-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_03_31 的数据，已达到最大重试次数
# 处理日期 2024_04_01 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "07bf5270-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_01 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "0d462a16-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_01 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "128f2e0a-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_01 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "17de7726-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_01 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1d543dc6-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_01 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "22e1ea04-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_01 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2840aa9e-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_01 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "2db422a8-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_01 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "334e1912-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_01 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "38aa24a0-95ae-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_04_01 的数据，已达到最大重试次数
# 处理日期 2024_04_02 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "3b3f6252-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_02 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "40f17834-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_02 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "46adb5e4-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_02 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "4c0e1cb8-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_02 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "5184e3a2-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_02 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "571f8a74-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_02 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "5c93e248-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_02 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "61f6db8c-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_02 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6774c3da-95ae-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_02 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6cb51cd2-95ae-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_04_02 的数据，已达到最大重试次数
# 日期 2024_04_09 没有有效的样本
# 处理日期 2024_04_15 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ea632e70-95af-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_15 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f0176368-95af-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_15 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "f587407a-95af-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_15 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "fad1cf00-95af-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_15 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "0037e736-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_15 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "0597bb34-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_15 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "0b0572f0-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_15 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "107893fc-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_15 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "15d84162-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_15 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "1b3000b4-95b0-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_04_15 的数据，已达到最大重试次数
# 日期 2024_04_18 没有有效的样本
# 处理日期 2024_04_20 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9ca226d6-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_20 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a235ca76-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_20 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a799dc6e-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_20 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ad06a0f6-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_20 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b292209a-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_20 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b7f32d7c-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_20 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "bd54b998-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_20 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c2a8ec84-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_20 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "c80c94c8-95b0-11ef-9f62-00155d6026b0"}
# 处理日期 2024_04_20 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "cd4de932-95b0-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_04_20 的数据，已达到最大重试次数
# 处理日期 2024_04_24 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "3f0a9caa-95b1-11ef-9f62-00155d6026b0"}
# 日期 2024_04_24 没有有效的样本
# 处理日期 2024_05_06 的数据时出错 (尝试 1/10): 系统未知异常. {"taskId": "a60f5b42-95b2-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_06 的数据时出错 (尝试 2/10): [AIEError]: 22820932, ab8fc6b0 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "ab8fc6b0-95b2-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_06 的数据时出错 (尝试 3/10): [AIEError]: 22820932, aeb2cd24 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "aeb2cd24-95b2-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_06 的数据时出错 (尝试 4/10): [AIEError]: 22820932, b1d25bd2 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "b1d25bd2-95b2-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_06 的数据时出错 (尝试 5/10): [AIEError]: 22820932, b4f24cb4 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "b4f24cb4-95b2-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_06 的数据时出错 (尝试 6/10): [AIEError]: 22820932, b811c366 正在调整计算资源，请稍等片刻重新执行aie.Initialize()进行初始化. {"taskId": "b811c366-95b2-11ef-9f62-00155d6026b0"}
# 日期 2024_05_06 没有有效的样本
# 日期 2024_05_08 没有有效的样本
# 处理日期 2024_05_11 的数据时出错 (尝试 1/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_05_11]. {"taskId": "50e595fe-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_11 的数据时出错 (尝试 2/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_05_11]. {"taskId": "53fffea0-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_11 的数据时出错 (尝试 3/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_05_11]. {"taskId": "571e16c6-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_11 的数据时出错 (尝试 4/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_05_11]. {"taskId": "5a389bba-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_11 的数据时出错 (尝试 5/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_05_11]. {"taskId": "5d4df278-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_11 的数据时出错 (尝试 6/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_05_11]. {"taskId": "60655370-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_11 的数据时出错 (尝试 7/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_05_11]. {"taskId": "6385a780-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_11 的数据时出错 (尝试 8/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_05_11]. {"taskId": "669f2432-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_11 的数据时出错 (尝试 9/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_05_11]. {"taskId": "69c74c98-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_11 的数据时出错 (尝试 10/10): [AIEError]: 22803021, 找不到数据[MODIS_MOD09GA_061_2024_05_11]. {"taskId": "6ce53778-95b3-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_05_11 的数据，已达到最大重试次数
# 处理日期 2024_05_13 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8c41c69a-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_13 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "91acfcee-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_13 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "970700e0-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_13 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9c346e04-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_13 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a14a4c10-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_13 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a684b332-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_13 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "ab998d2a-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_13 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b0f4c4ce-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_13 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "b61f9686-95b3-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_13 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "bb5d83c4-95b3-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_05_13 的数据，已达到最大重试次数
# 日期 2024_05_14 没有有效的样本
# 日期 2024_05_16 没有有效的样本
# 日期 2024_05_18 没有有效的样本
# 处理日期 2024_05_20 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "7359acaa-95b4-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_20 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "78c29242-95b4-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_20 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "7e2d2c56-95b4-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_20 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8375509e-95b4-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_20 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "88d00d40-95b4-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_20 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8e1d5ee2-95b4-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_20 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "938ab56e-95b4-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_20 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "98d94094-95b4-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_20 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "9e2368c2-95b4-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_20 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "a3b46a02-95b4-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_05_20 的数据，已达到最大重试次数
# 日期 2024_05_23 没有有效的样本
# 处理日期 2024_05_27 的数据时出错 (尝试 1/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "5c5e0e46-95b5-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_27 的数据时出错 (尝试 2/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "61e28c70-95b5-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_27 的数据时出错 (尝试 3/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6770cd00-95b5-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_27 的数据时出错 (尝试 4/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "6cc9e278-95b5-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_27 的数据时出错 (尝试 5/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "72173140-95b5-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_27 的数据时出错 (尝试 6/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "789b1c34-95b5-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_27 的数据时出错 (尝试 7/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "7df65734-95b5-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_27 的数据时出错 (尝试 8/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8329bc96-95b5-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_27 的数据时出错 (尝试 9/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "888886ea-95b5-11ef-9f62-00155d6026b0"}
# 处理日期 2024_05_27 的数据时出错 (尝试 10/10): [AIEError]: 22801010, 输入属性不存在:ndci,存在的属性有:[]. {"taskId": "8de24cb6-95b5-11ef-9f62-00155d6026b0"}
# 无法处理日期 2024_05_27 的数据，已达到最大重试次数

# %%
# 将结果保存到CSV，计算并打印缺失值的数量和比例
if valid_features:
    results_df = pd.DataFrame(valid_features)
    results_df['density_mean'] = valid_density_mean
    results_df['density_lower'] = valid_density_lower
    results_df['density_upper'] = valid_density_upper
    results_df['date'] = valid_dates

    # 计算缺失日期
    date_range = pd.date_range(start=min(valid_dates), end=max(valid_dates))
    missing_dates = date_range.difference(results_df['date'])
    missing_count = len(missing_dates)
    total_days = (max(valid_dates) - min(valid_dates)).days + 1
    missing_percentage = 100 * missing_count / total_days
    
    print(f"缺失日期数量: {missing_count}")
    print(f"缺失日期比例: {missing_percentage:.2f}%")
    print("缺失日期:")
    print(missing_dates)

    # 生成包含日期和遥感影像名称的文件名
    current_date = datetime.datetime.now().strftime("%Y%m%d")
    filename = f'特征和密度结果_MODIS_MOD09GA_061_{current_date}.csv'
    
    results_df.to_csv(filename, index=False)
    print(f"\n结果已保存到 '{filename}'")
else:
    print("无有效数据可保存")
# Out:
# 缺失日期数量: 381
# 缺失日期比例: 30.58%
# 缺失日期:
# DatetimeIndex(['2021-01-08', '2021-01-09', '2021-01-13', '2021-01-15',
#                '2021-01-18', '2021-01-29', '2021-01-30', '2021-02-07',
#                '2021-02-09', '2021-02-18',
#                ...
#                '2024-05-06', '2024-05-08', '2024-05-11', '2024-05-13',
#                '2024-05-14', '2024-05-16', '2024-05-18', '2024-05-20',
#                '2024-05-23', '2024-05-27'],
#               dtype='datetime64[ns]', length=381, freq=None)
#
# 结果已保存到 '特征和密度结果_MODIS_MOD09GA_061_20241029.csv'

# %%
# 生成包含缺失日期的完整数据集并进行线性插值填充
if valid_features:
    # 创建完整的日期范围
    full_date_range = pd.date_range(start=min(valid_dates), end=max(valid_dates))
    
    # 将现有数据转换为以日期为索引的DataFrame
    full_df = results_df.set_index('date')
    
    # 重新索引到完整的日期范围，这将自动为缺失的日期创建NaN值
    full_df = full_df.reindex(full_date_range)
    
    # 对所有列进行线性插值
    interpolated_df = full_df.interpolate(method='linear')
    
    # 重置索引，使日期成为一个列
    interpolated_df = interpolated_df.reset_index()
    interpolated_df = interpolated_df.rename(columns={'index': 'date'})
    
    # 保存插值后的结果到新的CSV文件
    interpolated_filename = f'特征和密度结果_MODIS_MOD09GA_061_{current_date}_插值填充.csv'
    interpolated_df.to_csv(interpolated_filename, index=False)
    print(f"\n插值填充后的结果已保存到 '{interpolated_filename}'")
    
    # 输出插值填充后的数据信息
    print(f"\n插值填充后的数据行数: {len(interpolated_df)}")
    print(f"插值填充前的数据行数: {len(results_df)}")
    print(f"填充的行数: {len(interpolated_df) - len(results_df)}")
else:
    print("无有效数据可进行插值填充")
# Out:
# 插值填充后的结果已保存到 '特征和密度结果_MODIS_MOD09GA_061_20241029_插值填充.csv'
#
# 插值填充后的数据行数: 1246
# 插值填充前的数据行数: 865
# 填充的行数: 381

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import os

# 获取当前工作目录
current_dir = os.getcwd()
print(f"当前工作目录: {current_dir}")

# 列出当前目录下的所有文件
files = os.listdir(current_dir)
print("当前目录下的文件:")
for file in files:
    print(file)

# 尝试读取CSV文件
try:
    df = pd.read_csv('/root/Download/Modis-algae-aliyun/aie-taihu/特征和密度结果_MODIS_MOD09GA_061_20241029_插值填充.csv')
    print("成功读取CSV文件")
except FileNotFoundError:
    print("未找到CSV文件，请检查文件名和路径是否正确")
    raise

df['date'] = pd.to_datetime(df['date'])

# 获取所有特征列名
features = df.columns.drop(['date'])

# 设置图表样式
plt.style.use('seaborn')

# 为每个特征创建单独的图表
for feature in features:
    plt.figure(figsize=(12, 6))
    plt.plot(df['date'], df[feature], label=feature)
    plt.title(f'{feature}随时间的变化')
    plt.xlabel('日期')
    plt.ylabel(feature)
    plt.legend()
    
    # 设置x轴日期格式
    plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
    plt.gca().xaxis.set_major_locator(mdates.MonthLocator())
    
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()





print("所有特征的时间序列图已生成完毕。")
# Out:
# 当前工作目录: /root/Download/Modis-algae-aliyun/aie-taihu
# 当前目录下的文件:
# 特征和密度结果_MODIS_MOD09GA_061_20241029_插值填充.csv
# 04-LSTM-modis++1025-read-train.ipynb
# 03-inversion-taihu-1021-density-moremoremoredays-LSTM.ipynb
# 03-LSTM-1024-predict.ipynb
# 02-inversion-taihu-1016-density-runone.ipynb
# 01-test-taihu.ipynb
# 01-test-taihu-1016-chla.ipynb
# 03-inversion-taihu-1019-density-moredays-RF .ipynb
# 00-tuoshan.csv
# 特征和密度结果_MODIS_MCD18C2_061_20241027_插值填充.csv
# 03-inversion-taihu-1019-density-moremoredays-RF.ipynb
# 00-lanshanzui.csv
# 03-LSTM-1024-read-train.ipynb
# 02-inversion-taihu-1016-density-runall-78.ipynb
# 04-LSTM-modis+MCD18C2+1027-read.ipynb
# 02-inversion-taihu-1016-chla.ipynb
# 01-test-taihu-1016-density.ipynb
# 特征和密度结果_MODIS_MOD09GA_061_20241029.csv
# 04-LSTM-modis++1025-predict.ipynb
# 00-readcsv.ipynb
# 03-inversion-taihu-1022-density-moremoremoredays-LSTM.ipynb
# 01-test-taihu-1016-NDCI.ipynb
# 03-inversion-taihu-1023-density-moremoremoredays-LSTM-1.ipynb
# 01-test-taihu-1015.ipynb
# 03-inversion-taihu-1020-density-moremoremoredays-RF.ipynb
# saved_models
# 02-inversion-taihu-1016-density-runall-78-penalty-参数优化失败.ipynb
# 04-LSTM-modis+MOD09GA+1028-read.ipynb
# 特征和密度结果_MODIS_MCD18C2_061_20241027.csv
# 04-LSTM-modis+MOD11A1+1027-read.ipynb
# 03-inversion-taihu-1019-density-morebands-RF.ipynb
# 02-inversion-taihu-1016-density-runall.ipynb
# 03-inversion-taihu-1018-density-morebands.ipynb
# 成功读取CSV文件
# /tmp/ipykernel_23840/3703384636.py:30: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# /tmp/ipykernel_23840/3703384636.py:46: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/3703384636.py:46: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/3703384636.py:46: UserWarning: Glyph 38543 (\N{CJK UNIFIED IDEOGRAPH-968F}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/3703384636.py:46: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/3703384636.py:46: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/3703384636.py:46: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/3703384636.py:46: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_23840/3703384636.py:46: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   plt.tight_layout()
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38543 (\N{CJK UNIFIED IDEOGRAPH-968F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26102 (\N{CJK UNIFIED IDEOGRAPH-65F6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38388 (\N{CJK UNIFIED IDEOGRAPH-95F4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 30340 (\N{CJK UNIFIED IDEOGRAPH-7684}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21464 (\N{CJK UNIFIED IDEOGRAPH-53D8}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21270 (\N{CJK UNIFIED IDEOGRAPH-5316}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26085 (\N{CJK UNIFIED IDEOGRAPH-65E5}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /root/.conda/envs/hydro/envs/aie-sdk/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 26399 (\N{CJK UNIFIED IDEOGRAPH-671F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# 所有特征的时间序列图已生成完毕。

# %% [markdown]
# # 保存LSTM模型

# %% [markdown]
# ## 2024年

# %% [markdown]
# 请你读取这个模型和数据，并进行预测，绘制结果图，并输出一些统计信息。这里的LSTM的时间窗口是10天，也就是说，我们使用历史10天的数据，进行LSTM的时间卷积处理，来预测第10天的密度。最后绘制2024年的对比图，包括实际数据和预测数据
