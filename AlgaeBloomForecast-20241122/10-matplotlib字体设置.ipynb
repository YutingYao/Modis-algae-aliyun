# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

# 设置字体
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimSun', 'DejaVu Sans']  # 中文字体
plt.rcParams['font.serif'] = ['Times New Roman']  # 英文字体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# 分别设置中英文字体,并设置较大字号
chinese_font = fm.FontProperties(fname='/root/Download/Modis-algae-aliyun/AlgaeBloomForecast-20241122/SIMSUN.TTC', size=14)
english_font = fm.FontProperties(fname='/root/Download/Modis-algae-aliyun/AlgaeBloomForecast-20241122/TIMES.TTF', size=14)

# 使用示例：
plt.plot([1, 2, 3], [4, 5, 6])
plt.title('测试 Test', fontproperties=chinese_font, fontsize=16)  # 标题字号设置为16
plt.xlabel('标签 X Label', fontproperties=chinese_font, fontsize=14)
plt.ylabel('标签 Y Label', fontproperties=chinese_font, fontsize=14)

# 设置坐标轴刻度字体为英文字体,增大刻度字号
plt.tick_params(axis='both', which='major', labelsize=12)  # 刻度字号设置为12
ax = plt.gca()
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontproperties(english_font)

# %% [markdown]
# dnf install -y texlive texlive-latex-extra texlive-fonts-recommended texlive-pictures texlive-science dvipng cm-super
#
# Error: Unable to find a match: texlive-latex-extra texlive-fonts-recommended texlive-pictures texlive-science cm-super

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np

# 使用内置数学渲染器而不是LaTeX
plt.rcParams['text.usetex'] = False
plt.rcParams['mathtext.fontset'] = 'dejavusans'  # 使用DejaVu Sans字体渲染数学公式

# 设置中英文字体
plt.rcParams['font.family'] = ['sans-serif']
plt.rcParams['font.sans-serif'] = ['SimSun', 'DejaVu Sans']  # 中文字体
plt.rcParams['font.serif'] = ['Times New Roman']  # 英文字体
plt.rcParams['axes.unicode_minus'] = False  # 解决负号显示问题

# 分别设置中英文字体,并设置较大字号
chinese_font = fm.FontProperties(fname='/root/Download/Modis-algae-aliyun/AlgaeBloomForecast-20241122/SIMSUN.TTC', size=14)
english_font = fm.FontProperties(fname='/root/Download/Modis-algae-aliyun/AlgaeBloomForecast-20241122/TIMES.TTF', size=14)

# 使用示例：包含数学公式
plt.plot([1, 2, 3], [4, 5, 6])
plt.title(r'$\alpha + \beta = \gamma$ 测试', fontproperties=chinese_font, fontsize=16)  # 使用内置数学渲染器
plt.xlabel(r'$x^2$ 标签', fontproperties=chinese_font, fontsize=14)
plt.ylabel(r'$\frac{dy}{dx}$ 标签', fontproperties=chinese_font, fontsize=14)

# 设置坐标轴刻度字体为英文字体,增大刻度字号
plt.tick_params(axis='both', which='major', labelsize=12)  # 刻度字号设置为12
ax = plt.gca()
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontproperties(english_font)
